# %%
#### bee hives
import requests
import numpy as np
import pandas as pd
from pprint import pprint
apikey = "15B191E7-B8C5-3AF1-9E28-97FD910F9119"
usda_url ="http://quickstats.nass.usda.gov/api/api_GET/?key=15B191E7-B8C5-3AF1-9E28-97FD910F9119&source_desc=SURVEY&commodity_desc=HONEY&agg_level_desc=STATE&param=short_desc"
usda_data= requests.get(usda_url).json()
usda_data
#extracted data using API key and converted into JSON
# Out:
# {'data': [{'county_name': '',
#    'end_code': '00',
#    'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'county_code': '',
#    'country_name': 'UNITED STATES',
#    'watershed_code': '00000000',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'year': 2020,
#    'asd_desc': '',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'freq_desc': 'ANNUAL',
#    'group_desc': 'SPECIALTY',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': '',
#    'location_desc': 'ALABAMA',
#    'state_alpha': 'AL',
#    'state_ansi': '01',
#    'source_desc': 'SURVEY',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_name': 'ALABAMA',
#    'Value': '5.43',
#    'congr_district_code': '',
#    'unit_desc': '$ / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'state_fips_code': '01',
#    'watershed_desc': '',
#    'country_code': '9000',
#    'load_time': '2021-03-18 15:00:29',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'CV (%)': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'begin_code': '00',
#    'week_ending': ''},
#   {'Value': '3.38',
#    'location_desc': 'ALABAMA',
#    'state_alpha': 'AL',
#    'source_desc': 'SURVEY',
#    'state_ansi': '01',
#    'state_name': 'ALABAMA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'CV (%)': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'week_ending': '',
#    'begin_code': '00',
#    'reference_period_desc': 'MARKETING YEAR',
#    'state_fips_code': '01',
#    'watershed_desc': '',
#    'congr_district_code': '',
#    'unit_desc': '$ / LB',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'load_time': '2021-03-18 15:00:29',
#    'country_code': '9000',
#    'county_code': '',
#    'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'country_name': 'UNITED STATES',
#    'watershed_code': '00000000',
#    'end_code': '00',
#    'county_name': '',
#    'county_ansi': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'region_desc': '',
#    'year': 2019,
#    'asd_desc': '',
#    'commodity_desc': 'HONEY',
#    'group_desc': 'SPECIALTY',
#    'freq_desc': 'ANNUAL',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB'},
#   {'end_code': '00',
#    'county_name': '',
#    'county_code': '',
#    'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'country_name': 'UNITED STATES',
#    'watershed_code': '00000000',
#    'region_desc': '',
#    'year': 2018,
#    'asd_desc': '',
#    'commodity_desc': 'HONEY',
#    'group_desc': 'SPECIALTY',
#    'freq_desc': 'ANNUAL',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'county_ansi': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'state_alpha': 'AL',
#    'location_desc': 'ALABAMA',
#    'state_ansi': '01',
#    'source_desc': 'SURVEY',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_name': 'ALABAMA',
#    'Value': '3.72',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'state_fips_code': '01',
#    'unit_desc': '$ / LB',
#    'congr_district_code': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'country_code': '9000',
#    'load_time': '2020-03-19 15:06:59',
#    'CV (%)': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'week_ending': '',
#    'begin_code': '00'},
#   {'location_desc': 'ARIZONA',
#    'state_alpha': 'AZ',
#    'state_ansi': '04',
#    'source_desc': 'SURVEY',
#    'state_name': 'ARIZONA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'Value': '2.18',
#    'unit_desc': '$ / LB',
#    'congr_district_code': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'state_fips_code': '04',
#    'load_time': '2021-03-18 15:00:29',
#    'country_code': '9000',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'CV (%)': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'begin_code': '00',
#    'week_ending': '',
#    'county_name': '',
#    'end_code': '00',
#    'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'county_code': '',
#    'country_name': 'UNITED STATES',
#    'watershed_code': '00000000',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'year': 2020,
#    'asd_desc': '',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'freq_desc': 'ANNUAL',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'group_desc': 'SPECIALTY',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': ''},
#   {'county_name': '',
#    'end_code': '00',
#    'country_name': 'UNITED STATES',
#    'watershed_code': '00000000',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'county_code': '',
#    'freq_desc': 'ANNUAL',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'group_desc': 'SPECIALTY',
#    'asd_desc': '',
#    'year': 2019,
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': '',
#    'state_ansi': '04',
#    'source_desc': 'SURVEY',
#    'state_name': 'ARIZONA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_alpha': 'AZ',
#    'location_desc': 'ARIZONA',
#    'Value': '2.04',
#    'country_code': '9000',
#    'load_time': '2021-03-18 15:00:29',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'congr_district_code': '',
#    'unit_desc': '$ / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'state_fips_code': '04',
#    'begin_code': '00',
#    'week_ending': '',
#    'domain_desc': 'TOTAL',
#    'asd_code': '',
#    'CV (%)': '',
#    'statisticcat_desc': 'PRICE RECEIVED'},
#   {'commodity_desc': 'HONEY',
#    'year': 2018,
#    'asd_desc': '',
#    'region_desc': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'freq_desc': 'ANNUAL',
#    'group_desc': 'SPECIALTY',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': '',
#    'county_name': '',
#    'end_code': '00',
#    'zip_5': '',
#    'agg_level_desc': 'STATE',
#    'county_code': '',
#    'watershed_code': '00000000',
#    'country_name': 'UNITED STATES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'congr_district_code': '',
#    'unit_desc': '$ / LB',
#    'state_fips_code': '04',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'country_code': '9000',
#    'load_time': '2020-03-19 15:06:59',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'CV (%)': '',
#    'begin_code': '00',
#    'week_ending': '',
#    'state_alpha': 'AZ',
#    'location_desc': 'ARIZONA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_name': 'ARIZONA',
#    'source_desc': 'SURVEY',
#    'state_ansi': '04',
#    'Value': '3.01'},
#   {'domain_desc': 'TOTAL',
#    'asd_code': '',
#    'CV (%)': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'begin_code': '00',
#    'week_ending': '',
#    'unit_desc': '$ / LB',
#    'congr_district_code': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'state_fips_code': '05',
#    'country_code': '9000',
#    'load_time': '2021-03-18 15:00:29',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'Value': '1.8',
#    'state_alpha': 'AR',
#    'location_desc': 'ARKANSAS',
#    'source_desc': 'SURVEY',
#    'state_ansi': '05',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_name': 'ARKANSAS',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': '',
#    'year': 2020,
#    'asd_desc': '',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'freq_desc': 'ANNUAL',
#    'group_desc': 'SPECIALTY',
#    'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'county_code': '',
#    'country_name': 'UNITED STATES',
#    'watershed_code': '00000000',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'county_name': '',
#    'end_code': '00'},
#   {'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': '',
#    'freq_desc': 'ANNUAL',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'group_desc': 'SPECIALTY',
#    'commodity_desc': 'HONEY',
#    'year': 2019,
#    'asd_desc': '',
#    'region_desc': '',
#    'watershed_code': '00000000',
#    'country_name': 'UNITED STATES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'zip_5': '',
#    'agg_level_desc': 'STATE',
#    'county_code': '',
#    'county_name': '',
#    'end_code': '00',
#    'begin_code': '00',
#    'week_ending': '',
#    'domain_desc': 'TOTAL',
#    'asd_code': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'CV (%)': '',
#    'country_code': '9000',
#    'load_time': '2021-03-18 15:00:29',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'congr_district_code': '',
#    'unit_desc': '$ / LB',
#    'watershed_desc': '',
#    'state_fips_code': '05',
#    'reference_period_desc': 'MARKETING YEAR',
#    'Value': '1.65',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_name': 'ARKANSAS',
#    'source_desc': 'SURVEY',
#    'state_ansi': '05',
#    'location_desc': 'ARKANSAS',
#    'state_alpha': 'AR'},
#   {'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'county_code': '',
#    'country_name': 'UNITED STATES',
#    'watershed_code': '00000000',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'county_name': '',
#    'end_code': '00',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': '',
#    'year': 2018,
#    'asd_desc': '',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'freq_desc': 'ANNUAL',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'group_desc': 'SPECIALTY',
#    'Value': '1.88',
#    'location_desc': 'ARKANSAS',
#    'state_alpha': 'AR',
#    'state_ansi': '05',
#    'source_desc': 'SURVEY',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_name': 'ARKANSAS',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'CV (%)': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'begin_code': '00',
#    'week_ending': '',
#    'unit_desc': '$ / LB',
#    'congr_district_code': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'state_fips_code': '05',
#    'watershed_desc': '',
#    'load_time': '2020-03-19 15:06:59',
#    'country_code': '9000',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES'},
#   {'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'state_fips_code': '06',
#    'congr_district_code': '',
#    'unit_desc': '$ / LB',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'country_code': '9000',
#    'load_time': '2021-03-18 15:00:29',
#    'CV (%)': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'domain_desc': 'TOTAL',
#    'asd_code': '',
#    'week_ending': '',
#    'begin_code': '00',
#    'location_desc': 'CALIFORNIA',
#    'state_alpha': 'CA',
#    'source_desc': 'SURVEY',
#    'state_ansi': '06',
#    'state_name': 'CALIFORNIA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'Value': '1.78',
#    'region_desc': '',
#    'year': 2020,
#    'asd_desc': '',
#    'commodity_desc': 'HONEY',
#    'group_desc': 'SPECIALTY',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'freq_desc': 'ANNUAL',
#    'county_ansi': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'end_code': '00',
#    'county_name': '',
#    'county_code': '',
#    'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'country_name': 'UNITED STATES',
#    'watershed_code': '00000000'},
#   {'county_name': '',
#    'end_code': '00',
#    'watershed_code': '00000000',
#    'country_name': 'UNITED STATES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'zip_5': '',
#    'agg_level_desc': 'STATE',
#    'county_code': '',
#    'freq_desc': 'ANNUAL',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'group_desc': 'SPECIALTY',
#    'commodity_desc': 'HONEY',
#    'asd_desc': '',
#    'year': 2019,
#    'region_desc': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_name': 'CALIFORNIA',
#    'state_ansi': '06',
#    'source_desc': 'SURVEY',
#    'state_alpha': 'CA',
#    'location_desc': 'CALIFORNIA',
#    'Value': '1.6',
#    'country_code': '9000',
#    'load_time': '2021-03-18 15:00:29',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'congr_district_code': '',
#    'unit_desc': '$ / LB',
#    'watershed_desc': '',
#    'state_fips_code': '06',
#    'reference_period_desc': 'MARKETING YEAR',
#    'begin_code': '00',
#    'week_ending': '',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'CV (%)': ''},
#   {'end_code': '00',
#    'county_name': '',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'country_name': 'UNITED STATES',
#    'watershed_code': '00000000',
#    'county_code': '',
#    'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'group_desc': 'SPECIALTY',
#    'freq_desc': 'ANNUAL',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'region_desc': '',
#    'year': 2018,
#    'asd_desc': '',
#    'commodity_desc': 'HONEY',
#    'county_ansi': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'state_ansi': '06',
#    'source_desc': 'SURVEY',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_name': 'CALIFORNIA',
#    'location_desc': 'CALIFORNIA',
#    'state_alpha': 'CA',
#    'Value': '2.11',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'country_code': '9000',
#    'load_time': '2020-03-19 15:06:59',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'state_fips_code': '06',
#    'unit_desc': '$ / LB',
#    'congr_district_code': '',
#    'week_ending': '',
#    'begin_code': '00',
#    'CV (%)': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'domain_desc': 'TOTAL',
#    'asd_code': ''},
#   {'Value': '2.09',
#    'state_name': 'COLORADO',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'source_desc': 'SURVEY',
#    'state_ansi': '08',
#    'location_desc': 'COLORADO',
#    'state_alpha': 'CO',
#    'begin_code': '00',
#    'week_ending': '',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'CV (%)': '',
#    'load_time': '2021-03-18 15:00:29',
#    'country_code': '9000',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'congr_district_code': '',
#    'unit_desc': '$ / LB',
#    'state_fips_code': '08',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_code': '00000000',
#    'country_name': 'UNITED STATES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'zip_5': '',
#    'agg_level_desc': 'STATE',
#    'county_code': '',
#    'county_name': '',
#    'end_code': '00',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': '',
#    'freq_desc': 'ANNUAL',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'group_desc': 'SPECIALTY',
#    'commodity_desc': 'HONEY',
#    'year': 2020,
#    'asd_desc': '',
#    'region_desc': ''},
#   {'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'state_fips_code': '08',
#    'congr_district_code': '',
#    'unit_desc': '$ / LB',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'load_time': '2021-03-18 15:00:29',
#    'country_code': '9000',
#    'CV (%)': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'week_ending': '',
#    'begin_code': '00',
#    'state_alpha': 'CO',
#    'location_desc': 'COLORADO',
#    'state_ansi': '08',
#    'source_desc': 'SURVEY',
#    'state_name': 'COLORADO',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'Value': '2.34',
#    'region_desc': '',
#    'asd_desc': '',
#    'year': 2019,
#    'commodity_desc': 'HONEY',
#    'group_desc': 'SPECIALTY',
#    'freq_desc': 'ANNUAL',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'county_ansi': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'end_code': '00',
#    'county_name': '',
#    'county_code': '',
#    'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'country_name': 'UNITED STATES',
#    'watershed_code': '00000000'},
#   {'Value': '2.05',
#    'location_desc': 'COLORADO',
#    'state_alpha': 'CO',
#    'source_desc': 'SURVEY',
#    'state_ansi': '08',
#    'state_name': 'COLORADO',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'CV (%)': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'domain_desc': 'TOTAL',
#    'asd_code': '',
#    'week_ending': '',
#    'begin_code': '00',
#    'reference_period_desc': 'MARKETING YEAR',
#    'state_fips_code': '08',
#    'watershed_desc': '',
#    'unit_desc': '$ / LB',
#    'congr_district_code': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'load_time': '2020-03-19 15:06:59',
#    'country_code': '9000',
#    'county_code': '',
#    'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'country_name': 'UNITED STATES',
#    'watershed_code': '00000000',
#    'end_code': '00',
#    'county_name': '',
#    'county_ansi': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'region_desc': '',
#    'asd_desc': '',
#    'year': 2018,
#    'commodity_desc': 'HONEY',
#    'group_desc': 'SPECIALTY',
#    'freq_desc': 'ANNUAL',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB'},
#   {'source_desc': 'SURVEY',
#    'state_ansi': '12',
#    'state_name': 'FLORIDA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_alpha': 'FL',
#    'location_desc': 'FLORIDA',
#    'Value': '2.28',
#    'load_time': '2021-03-18 15:00:29',
#    'country_code': '9000',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'unit_desc': '$ / LB',
#    'congr_district_code': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'state_fips_code': '12',
#    'watershed_desc': '',
#    'begin_code': '00',
#    'week_ending': '',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'CV (%)': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'county_name': '',
#    'end_code': '00',
#    'country_name': 'UNITED STATES',
#    'watershed_code': '00000000',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'county_code': '',
#    'freq_desc': 'ANNUAL',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'group_desc': 'SPECIALTY',
#    'year': 2020,
#    'asd_desc': '',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': ''},
#   {'zip_5': '',
#    'agg_level_desc': 'STATE',
#    'county_code': '',
#    'watershed_code': '00000000',
#    'country_name': 'UNITED STATES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'county_name': '',
#    'end_code': '00',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': '',
#    'commodity_desc': 'HONEY',
#    'year': 2019,
#    'asd_desc': '',
#    'region_desc': '',
#    'freq_desc': 'ANNUAL',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'group_desc': 'SPECIALTY',
#    'Value': '2.46',
#    'location_desc': 'FLORIDA',
#    'state_alpha': 'FL',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_name': 'FLORIDA',
#    'source_desc': 'SURVEY',
#    'state_ansi': '12',
#    'domain_desc': 'TOTAL',
#    'asd_code': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'CV (%)': '',
#    'begin_code': '00',
#    'week_ending': '',
#    'congr_district_code': '',
#    'unit_desc': '$ / LB',
#    'state_fips_code': '12',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'load_time': '2021-03-18 15:00:29',
#    'country_code': '9000',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES'},
#   {'end_code': '00',
#    'county_name': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'watershed_code': '00000000',
#    'country_name': 'UNITED STATES',
#    'county_code': '',
#    'zip_5': '',
#    'agg_level_desc': 'STATE',
#    'group_desc': 'SPECIALTY',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'freq_desc': 'ANNUAL',
#    'region_desc': '',
#    'commodity_desc': 'HONEY',
#    'year': 2018,
#    'asd_desc': '',
#    'county_ansi': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_name': 'FLORIDA',
#    'state_ansi': '12',
#    'source_desc': 'SURVEY',
#    'state_alpha': 'FL',
#    'location_desc': 'FLORIDA',
#    'Value': '2.4',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'country_code': '9000',
#    'load_time': '2020-03-19 15:06:59',
#    'state_fips_code': '12',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'congr_district_code': '',
#    'unit_desc': '$ / LB',
#    'week_ending': '',
#    'begin_code': '00',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'CV (%)': '',
#    'domain_desc': 'TOTAL',
#    'asd_code': ''},
#   {'domain_desc': 'TOTAL',
#    'asd_code': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'CV (%)': '',
#    'begin_code': '00',
#    'week_ending': '',
#    'unit_desc': '$ / LB',
#    'congr_district_code': '',
#    'state_fips_code': '13',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'load_time': '2021-03-18 15:00:29',
#    'country_code': '9000',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'Value': '2.36',
#    'state_alpha': 'GA',
#    'location_desc': 'GEORGIA',
#    'state_name': 'GEORGIA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_ansi': '13',
#    'source_desc': 'SURVEY',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': '',
#    'commodity_desc': 'HONEY',
#    'year': 2020,
#    'asd_desc': '',
#    'region_desc': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'freq_desc': 'ANNUAL',
#    'group_desc': 'SPECIALTY',
#    'zip_5': '',
#    'agg_level_desc': 'STATE',
#    'county_code': '',
#    'watershed_code': '00000000',
#    'country_name': 'UNITED STATES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'county_name': '',
#    'end_code': '00'},
#   {'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'CV (%)': '',
#    'begin_code': '00',
#    'week_ending': '',
#    'congr_district_code': '',
#    'unit_desc': '$ / LB',
#    'state_fips_code': '13',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'country_code': '9000',
#    'load_time': '2021-03-18 15:00:29',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'Value': '2.67',
#    'location_desc': 'GEORGIA',
#    'state_alpha': 'GA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_name': 'GEORGIA',
#    'state_ansi': '13',
#    'source_desc': 'SURVEY',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': '',
#    'commodity_desc': 'HONEY',
#    'year': 2019,
#    'asd_desc': '',
#    'region_desc': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'freq_desc': 'ANNUAL',
#    'group_desc': 'SPECIALTY',
#    'zip_5': '',
#    'agg_level_desc': 'STATE',
#    'county_code': '',
#    'watershed_code': '00000000',
#    'country_name': 'UNITED STATES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'county_name': '',
#    'end_code': '00'},
#   {'group_desc': 'SPECIALTY',
#    'freq_desc': 'ANNUAL',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'region_desc': '',
#    'commodity_desc': 'HONEY',
#    'asd_desc': '',
#    'year': 2018,
#    'county_ansi': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'end_code': '00',
#    'county_name': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'watershed_code': '00000000',
#    'country_name': 'UNITED STATES',
#    'county_code': '',
#    'zip_5': '',
#    'agg_level_desc': 'STATE',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'country_code': '9000',
#    'load_time': '2020-03-19 15:06:59',
#    'state_fips_code': '13',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'unit_desc': '$ / LB',
#    'congr_district_code': '',
#    'week_ending': '',
#    'begin_code': '00',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'CV (%)': '',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'state_name': 'GEORGIA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'source_desc': 'SURVEY',
#    'state_ansi': '13',
#    'location_desc': 'GEORGIA',
#    'state_alpha': 'GA',
#    'Value': '2.76'},
#   {'Value': '1.61',
#    'location_desc': 'HAWAII',
#    'state_alpha': 'HI',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_name': 'HAWAII',
#    'state_ansi': '15',
#    'source_desc': 'SURVEY',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'CV (%)': '',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'week_ending': '',
#    'begin_code': '00',
#    'watershed_desc': '',
#    'state_fips_code': '15',
#    'reference_period_desc': 'MARKETING YEAR',
#    'congr_district_code': '',
#    'unit_desc': '$ / LB',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'country_code': '9000',
#    'load_time': '2021-03-18 15:00:29',
#    'county_code': '',
#    'zip_5': '',
#    'agg_level_desc': 'STATE',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'watershed_code': '00000000',
#    'country_name': 'UNITED STATES',
#    'end_code': '00',
#    'county_name': '',
#    'county_ansi': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'region_desc': '',
#    'commodity_desc': 'HONEY',
#    'year': 2020,
#    'asd_desc': '',
#    'group_desc': 'SPECIALTY',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'freq_desc': 'ANNUAL'},
#   {'state_name': 'HAWAII',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_ansi': '15',
#    'source_desc': 'SURVEY',
#    'location_desc': 'HAWAII',
#    'state_alpha': 'HI',
#    'Value': '1.3',
#    'load_time': '2021-03-18 15:00:29',
#    'country_code': '9000',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'congr_district_code': '',
#    'unit_desc': '$ / LB',
#    'watershed_desc': '',
#    'state_fips_code': '15',
#    'reference_period_desc': 'MARKETING YEAR',
#    'begin_code': '00',
#    'week_ending': '',
#    'domain_desc': 'TOTAL',
#    'asd_code': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'CV (%)': '',
#    'county_name': '',
#    'end_code': '00',
#    'watershed_code': '00000000',
#    'country_name': 'UNITED STATES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'zip_5': '',
#    'agg_level_desc': 'STATE',
#    'county_code': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'freq_desc': 'ANNUAL',
#    'group_desc': 'SPECIALTY',
#    'commodity_desc': 'HONEY',
#    'year': 2019,
#    'asd_desc': '',
#    'region_desc': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': ''},
#   {'county_name': '',
#    'end_code': '00',
#    'country_name': 'UNITED STATES',
#    'watershed_code': '00000000',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'county_code': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'freq_desc': 'ANNUAL',
#    'group_desc': 'SPECIALTY',
#    'year': 2018,
#    'asd_desc': '',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': '',
#    'source_desc': 'SURVEY',
#    'state_ansi': '15',
#    'state_name': 'HAWAII',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'location_desc': 'HAWAII',
#    'state_alpha': 'HI',
#    'Value': '1.92',
#    'country_code': '9000',
#    'load_time': '2020-03-19 15:06:59',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'congr_district_code': '',
#    'unit_desc': '$ / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'state_fips_code': '15',
#    'begin_code': '00',
#    'week_ending': '',
#    'domain_desc': 'TOTAL',
#    'asd_code': '',
#    'CV (%)': '',
#    'statisticcat_desc': 'PRICE RECEIVED'},
#   {'begin_code': '00',
#    'week_ending': '',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'CV (%)': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'load_time': '2021-03-18 15:00:29',
#    'country_code': '9000',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'unit_desc': '$ / LB',
#    'congr_district_code': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'state_fips_code': '16',
#    'Value': '1.75',
#    'source_desc': 'SURVEY',
#    'state_ansi': '16',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_name': 'IDAHO',
#    'state_alpha': 'ID',
#    'location_desc': 'IDAHO',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': '',
#    'freq_desc': 'ANNUAL',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'group_desc': 'SPECIALTY',
#    'asd_desc': '',
#    'year': 2020,
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'country_name': 'UNITED STATES',
#    'watershed_code': '00000000',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'county_code': '',
#    'county_name': '',
#    'end_code': '00'},
#   {'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'freq_desc': 'ANNUAL',
#    'group_desc': 'SPECIALTY',
#    'year': 2019,
#    'asd_desc': '',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'country_name': 'UNITED STATES',
#    'watershed_code': '00000000',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'county_code': '',
#    'county_name': '',
#    'end_code': '00',
#    'begin_code': '00',
#    'week_ending': '',
#    'domain_desc': 'TOTAL',
#    'asd_code': '',
#    'CV (%)': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'load_time': '2021-03-18 15:00:29',
#    'country_code': '9000',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'unit_desc': '$ / LB',
#    'congr_district_code': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'state_fips_code': '16',
#    'watershed_desc': '',
#    'Value': '1.62',
#    'source_desc': 'SURVEY',
#    'state_ansi': '16',
#    'state_name': 'IDAHO',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'location_desc': 'IDAHO',
#    'state_alpha': 'ID'},
#   {'county_ansi': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'group_desc': 'SPECIALTY',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'freq_desc': 'ANNUAL',
#    'region_desc': '',
#    'commodity_desc': 'HONEY',
#    'year': 2018,
#    'asd_desc': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'watershed_code': '00000000',
#    'country_name': 'UNITED STATES',
#    'county_code': '',
#    'zip_5': '',
#    'agg_level_desc': 'STATE',
#    'end_code': '00',
#    'county_name': '',
#    'week_ending': '',
#    'begin_code': '00',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'CV (%)': '',
#    'domain_desc': 'TOTAL',
#    'asd_code': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'load_time': '2020-03-19 15:06:59',
#    'country_code': '9000',
#    'watershed_desc': '',
#    'state_fips_code': '16',
#    'reference_period_desc': 'MARKETING YEAR',
#    'congr_district_code': '',
#    'unit_desc': '$ / LB',
#    'Value': '1.96',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_name': 'IDAHO',
#    'source_desc': 'SURVEY',
#    'state_ansi': '16',
#    'state_alpha': 'ID',
#    'location_desc': 'IDAHO'},
#   {'begin_code': '00',
#    'week_ending': '',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'CV (%)': '',
#    'country_code': '9000',
#    'load_time': '2021-03-18 15:00:29',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'unit_desc': '$ / LB',
#    'congr_district_code': '',
#    'watershed_desc': '',
#    'state_fips_code': '17',
#    'reference_period_desc': 'MARKETING YEAR',
#    'Value': '5.56',
#    'state_name': 'ILLINOIS',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_ansi': '17',
#    'source_desc': 'SURVEY',
#    'location_desc': 'ILLINOIS',
#    'state_alpha': 'IL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'freq_desc': 'ANNUAL',
#    'group_desc': 'SPECIALTY',
#    'commodity_desc': 'HONEY',
#    'asd_desc': '',
#    'year': 2020,
#    'region_desc': '',
#    'watershed_code': '00000000',
#    'country_name': 'UNITED STATES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'zip_5': '',
#    'agg_level_desc': 'STATE',
#    'county_code': '',
#    'county_name': '',
#    'end_code': '00'},
#   {'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': '',
#    'asd_desc': '',
#    'year': 2019,
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'freq_desc': 'ANNUAL',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'group_desc': 'SPECIALTY',
#    'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'county_code': '',
#    'country_name': 'UNITED STATES',
#    'watershed_code': '00000000',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'county_name': '',
#    'end_code': '00',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'CV (%)': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'begin_code': '00',
#    'week_ending': '',
#    'unit_desc': '$ / LB',
#    'congr_district_code': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'state_fips_code': '17',
#    'watershed_desc': '',
#    'country_code': '9000',
#    'load_time': '2021-03-18 15:00:29',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'Value': '4.12',
#    'state_alpha': 'IL',
#    'location_desc': 'ILLINOIS',
#    'state_ansi': '17',
#    'source_desc': 'SURVEY',
#    'state_name': 'ILLINOIS',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES'},
#   {'asd_desc': '',
#    'year': 2018,
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'freq_desc': 'ANNUAL',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'group_desc': 'SPECIALTY',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': '',
#    'county_name': '',
#    'end_code': '00',
#    'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'county_code': '',
#    'country_name': 'UNITED STATES',
#    'watershed_code': '00000000',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'unit_desc': '$ / LB',
#    'congr_district_code': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'state_fips_code': '17',
#    'watershed_desc': '',
#    'load_time': '2020-03-19 15:06:59',
#    'country_code': '9000',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'CV (%)': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'begin_code': '00',
#    'week_ending': '',
#    'location_desc': 'ILLINOIS',
#    'state_alpha': 'IL',
#    'state_ansi': '17',
#    'source_desc': 'SURVEY',
#    'state_name': 'ILLINOIS',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'Value': '4.83'},
#   {'state_fips_code': '18',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'congr_district_code': '',
#    'unit_desc': '$ / LB',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'country_code': '9000',
#    'load_time': '2021-03-18 15:00:29',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'CV (%)': '',
#    'domain_desc': 'TOTAL',
#    'asd_code': '',
#    'week_ending': '',
#    'begin_code': '00',
#    'state_alpha': 'IN',
#    'location_desc': 'INDIANA',
#    'state_name': 'INDIANA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'source_desc': 'SURVEY',
#    'state_ansi': '18',
#    'Value': '4.14',
#    'region_desc': '',
#    'commodity_desc': 'HONEY',
#    'year': 2020,
#    'asd_desc': '',
#    'group_desc': 'SPECIALTY',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'freq_desc': 'ANNUAL',
#    'county_ansi': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'end_code': '00',
#    'county_name': '',
#    'county_code': '',
#    'zip_5': '',
#    'agg_level_desc': 'STATE',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'watershed_code': '00000000',
#    'country_name': 'UNITED STATES'},
#   {'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'freq_desc': 'ANNUAL',
#    'group_desc': 'SPECIALTY',
#    'asd_desc': '',
#    'year': 2019,
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'country_name': 'UNITED STATES',
#    'watershed_code': '00000000',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'county_code': '',
#    'county_name': '',
#    'end_code': '00',
#    'begin_code': '00',
#    'week_ending': '',
#    'domain_desc': 'TOTAL',
#    'asd_code': '',
#    'CV (%)': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'country_code': '9000',
#    'load_time': '2021-03-18 15:00:29',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'unit_desc': '$ / LB',
#    'congr_district_code': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'state_fips_code': '18',
#    'watershed_desc': '',
#    'Value': '3.78',
#    'source_desc': 'SURVEY',
#    'state_ansi': '18',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_name': 'INDIANA',
#    'state_alpha': 'IN',
#    'location_desc': 'INDIANA'},
#   {'location_desc': 'INDIANA',
#    'state_alpha': 'IN',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_name': 'INDIANA',
#    'source_desc': 'SURVEY',
#    'state_ansi': '18',
#    'Value': '3.58',
#    'unit_desc': '$ / LB',
#    'congr_district_code': '',
#    'state_fips_code': '18',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'country_code': '9000',
#    'load_time': '2020-03-19 15:06:59',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'CV (%)': '',
#    'begin_code': '00',
#    'week_ending': '',
#    'county_name': '',
#    'end_code': '00',
#    'zip_5': '',
#    'agg_level_desc': 'STATE',
#    'county_code': '',
#    'watershed_code': '00000000',
#    'country_name': 'UNITED STATES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'commodity_desc': 'HONEY',
#    'asd_desc': '',
#    'year': 2018,
#    'region_desc': '',
#    'freq_desc': 'ANNUAL',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'group_desc': 'SPECIALTY',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': ''},
#   {'Value': '2.59',
#    'location_desc': 'IOWA',
#    'state_alpha': 'IA',
#    'state_name': 'IOWA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_ansi': '19',
#    'source_desc': 'SURVEY',
#    'domain_desc': 'TOTAL',
#    'asd_code': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'CV (%)': '',
#    'begin_code': '00',
#    'week_ending': '',
#    'congr_district_code': '',
#    'unit_desc': '$ / LB',
#    'watershed_desc': '',
#    'state_fips_code': '19',
#    'reference_period_desc': 'MARKETING YEAR',
#    'load_time': '2021-03-18 15:00:29',
#    'country_code': '9000',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'zip_5': '',
#    'agg_level_desc': 'STATE',
#    'county_code': '',
#    'watershed_code': '00000000',
#    'country_name': 'UNITED STATES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'county_name': '',
#    'end_code': '00',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': '',
#    'commodity_desc': 'HONEY',
#    'year': 2020,
#    'asd_desc': '',
#    'region_desc': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'freq_desc': 'ANNUAL',
#    'group_desc': 'SPECIALTY'},
#   {'state_ansi': '19',
#    'source_desc': 'SURVEY',
#    'state_name': 'IOWA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_alpha': 'IA',
#    'location_desc': 'IOWA',
#    'Value': '2.35',
#    'load_time': '2021-03-18 15:00:29',
#    'country_code': '9000',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'unit_desc': '$ / LB',
#    'congr_district_code': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'state_fips_code': '19',
#    'watershed_desc': '',
#    'begin_code': '00',
#    'week_ending': '',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'CV (%)': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'county_name': '',
#    'end_code': '00',
#    'country_name': 'UNITED STATES',
#    'watershed_code': '00000000',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'county_code': '',
#    'freq_desc': 'ANNUAL',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'group_desc': 'SPECIALTY',
#    'year': 2019,
#    'asd_desc': '',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': ''},
#   {'region_desc': '',
#    'commodity_desc': 'HONEY',
#    'asd_desc': '',
#    'year': 2018,
#    'group_desc': 'SPECIALTY',
#    'freq_desc': 'ANNUAL',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'county_ansi': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'end_code': '00',
#    'county_name': '',
#    'county_code': '',
#    'zip_5': '',
#    'agg_level_desc': 'STATE',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'watershed_code': '00000000',
#    'country_name': 'UNITED STATES',
#    'state_fips_code': '19',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'unit_desc': '$ / LB',
#    'congr_district_code': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'country_code': '9000',
#    'load_time': '2020-03-19 15:06:59',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'CV (%)': '',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'week_ending': '',
#    'begin_code': '00',
#    'state_alpha': 'IA',
#    'location_desc': 'IOWA',
#    'state_name': 'IOWA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'source_desc': 'SURVEY',
#    'state_ansi': '19',
#    'Value': '2.4'},
#   {'source_desc': 'SURVEY',
#    'state_ansi': '20',
#    'state_name': 'KANSAS',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'location_desc': 'KANSAS',
#    'state_alpha': 'KS',
#    'Value': '2.93',
#    'country_code': '9000',
#    'load_time': '2021-03-18 15:00:29',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'congr_district_code': '',
#    'unit_desc': '$ / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'state_fips_code': '20',
#    'watershed_desc': '',
#    'begin_code': '00',
#    'week_ending': '',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'CV (%)': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'county_name': '',
#    'end_code': '00',
#    'country_name': 'UNITED STATES',
#    'watershed_code': '00000000',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'county_code': '',
#    'freq_desc': 'ANNUAL',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'group_desc': 'SPECIALTY',
#    'year': 2020,
#    'asd_desc': '',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': ''},
#   {'begin_code': '00',
#    'week_ending': '',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'CV (%)': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'country_code': '9000',
#    'load_time': '2021-03-18 15:00:29',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'congr_district_code': '',
#    'unit_desc': '$ / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'state_fips_code': '20',
#    'watershed_desc': '',
#    'Value': '2.35',
#    'state_ansi': '20',
#    'source_desc': 'SURVEY',
#    'state_name': 'KANSAS',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'location_desc': 'KANSAS',
#    'state_alpha': 'KS',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'freq_desc': 'ANNUAL',
#    'group_desc': 'SPECIALTY',
#    'year': 2019,
#    'asd_desc': '',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'country_name': 'UNITED STATES',
#    'watershed_code': '00000000',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'county_code': '',
#    'county_name': '',
#    'end_code': '00'},
#   {'domain_desc': 'TOTAL',
#    'asd_code': '',
#    'CV (%)': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'begin_code': '00',
#    'week_ending': '',
#    'congr_district_code': '',
#    'unit_desc': '$ / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'state_fips_code': '20',
#    'watershed_desc': '',
#    'country_code': '9000',
#    'load_time': '2020-03-19 15:06:59',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'Value': '3.1',
#    'location_desc': 'KANSAS',
#    'state_alpha': 'KS',
#    'source_desc': 'SURVEY',
#    'state_ansi': '20',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_name': 'KANSAS',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': '',
#    'asd_desc': '',
#    'year': 2018,
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'freq_desc': 'ANNUAL',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'group_desc': 'SPECIALTY',
#    'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'county_code': '',
#    'country_name': 'UNITED STATES',
#    'watershed_code': '00000000',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'county_name': '',
#    'end_code': '00'},
#   {'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'county_code': '',
#    'country_name': 'UNITED STATES',
#    'watershed_code': '00000000',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'county_name': '',
#    'end_code': '00',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': '',
#    'year': 2020,
#    'asd_desc': '',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'freq_desc': 'ANNUAL',
#    'group_desc': 'SPECIALTY',
#    'Value': '6.25',
#    'location_desc': 'KENTUCKY',
#    'state_alpha': 'KY',
#    'state_ansi': '21',
#    'source_desc': 'SURVEY',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_name': 'KENTUCKY',
#    'domain_desc': 'TOTAL',
#    'asd_code': '',
#    'CV (%)': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'begin_code': '00',
#    'week_ending': '',
#    'unit_desc': '$ / LB',
#    'congr_district_code': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'state_fips_code': '21',
#    'watershed_desc': '',
#    'load_time': '2021-03-18 15:00:29',
#    'country_code': '9000',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES'},
#   {'county_ansi': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'group_desc': 'SPECIALTY',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'freq_desc': 'ANNUAL',
#    'region_desc': '',
#    'year': 2019,
#    'asd_desc': '',
#    'commodity_desc': 'HONEY',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'country_name': 'UNITED STATES',
#    'watershed_code': '00000000',
#    'county_code': '',
#    'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'end_code': '00',
#    'county_name': '',
#    'week_ending': '',
#    'begin_code': '00',
#    'CV (%)': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'domain_desc': 'TOTAL',
#    'asd_code': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'country_code': '9000',
#    'load_time': '2021-03-18 15:00:29',
#    'reference_period_desc': 'MARKETING YEAR',
#    'state_fips_code': '21',
#    'watershed_desc': '',
#    'congr_district_code': '',
#    'unit_desc': '$ / LB',
#    'Value': '4.66',
#    'state_ansi': '21',
#    'source_desc': 'SURVEY',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_name': 'KENTUCKY',
#    'state_alpha': 'KY',
#    'location_desc': 'KENTUCKY'},
#   {'commodity_desc': 'HONEY',
#    'asd_desc': '',
#    'year': 2018,
#    'region_desc': '',
#    'freq_desc': 'ANNUAL',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'group_desc': 'SPECIALTY',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': '',
#    'county_name': '',
#    'end_code': '00',
#    'zip_5': '',
#    'agg_level_desc': 'STATE',
#    'county_code': '',
#    'watershed_code': '00000000',
#    'country_name': 'UNITED STATES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'congr_district_code': '',
#    'unit_desc': '$ / LB',
#    'state_fips_code': '21',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'country_code': '9000',
# ...
#    'reference_period_desc': 'MARKETING YEAR',
#    'congr_district_code': '',
#    'unit_desc': 'CENTS / LB',
#    'week_ending': '',
#    'begin_code': '00',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'CV (%)': '',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'end_code': '00',
#    'county_name': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'watershed_code': '00000000',
#    'country_name': 'UNITED STATES',
#    'county_code': '',
#    'zip_5': '',
#    'agg_level_desc': 'STATE',
#    'group_desc': 'SPECIALTY',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'freq_desc': 'ANNUAL',
#    'region_desc': '',
#    'commodity_desc': 'HONEY',
#    'asd_desc': '',
#    'year': 2010,
#    'county_ansi': '',
#    'domaincat_desc': 'NOT SPECIFIED'},
#   {'country_name': 'UNITED STATES',
#    'watershed_code': '00000000',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'county_code': '',
#    'county_name': '',
#    'end_code': '00',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'freq_desc': 'ANNUAL',
#    'group_desc': 'SPECIALTY',
#    'asd_desc': '',
#    'year': 2009,
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'Value': '138',
#    'state_ansi': '38',
#    'source_desc': 'SURVEY',
#    'state_name': 'NORTH DAKOTA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_alpha': 'ND',
#    'location_desc': 'NORTH DAKOTA',
#    'begin_code': '00',
#    'week_ending': '',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'CV (%)': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'load_time': '2012-01-01 00:00:00',
#    'country_code': '9000',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'unit_desc': 'CENTS / LB',
#    'congr_district_code': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'state_fips_code': '38',
#    'watershed_desc': ''},
#   {'group_desc': 'SPECIALTY',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'freq_desc': 'ANNUAL',
#    'region_desc': '',
#    'year': 2008,
#    'asd_desc': '',
#    'commodity_desc': 'HONEY',
#    'county_ansi': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'end_code': '00',
#    'county_name': '',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'country_name': 'UNITED STATES',
#    'watershed_code': '00000000',
#    'county_code': '',
#    'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'country_code': '9000',
#    'load_time': '2012-01-01 00:00:00',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'state_fips_code': '38',
#    'unit_desc': 'CENTS / LB',
#    'congr_district_code': '',
#    'week_ending': '',
#    'begin_code': '00',
#    'CV (%)': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'domain_desc': 'TOTAL',
#    'asd_code': '',
#    'source_desc': 'SURVEY',
#    'state_ansi': '38',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_name': 'NORTH DAKOTA',
#    'state_alpha': 'ND',
#    'location_desc': 'NORTH DAKOTA',
#    'Value': '136'},
#   {'county_name': '',
#    'end_code': '00',
#    'country_name': 'UNITED STATES',
#    'watershed_code': '00000000',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'county_code': '',
#    'freq_desc': 'ANNUAL',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'group_desc': 'SPECIALTY',
#    'year': 2007,
#    'asd_desc': '',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': '',
#    'source_desc': 'SURVEY',
#    'state_ansi': '38',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_name': 'NORTH DAKOTA',
#    'state_alpha': 'ND',
#    'location_desc': 'NORTH DAKOTA',
#    'Value': '96',
#    'country_code': '9000',
#    'load_time': '2012-01-01 00:00:00',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'congr_district_code': '',
#    'unit_desc': 'CENTS / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'state_fips_code': '38',
#    'begin_code': '00',
#    'week_ending': '',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'CV (%)': '',
#    'statisticcat_desc': 'PRICE RECEIVED'},
#   {'year': 2006,
#    'asd_desc': '',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'freq_desc': 'ANNUAL',
#    'group_desc': 'SPECIALTY',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': '',
#    'county_name': '',
#    'end_code': '00',
#    'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'county_code': '',
#    'country_name': 'UNITED STATES',
#    'watershed_code': '00000000',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'unit_desc': 'CENTS / LB',
#    'congr_district_code': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'state_fips_code': '38',
#    'watershed_desc': '',
#    'country_code': '9000',
#    'load_time': '2012-01-01 00:00:00',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'CV (%)': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'begin_code': '00',
#    'week_ending': '',
#    'location_desc': 'NORTH DAKOTA',
#    'state_alpha': 'ND',
#    'source_desc': 'SURVEY',
#    'state_ansi': '38',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_name': 'NORTH DAKOTA',
#    'Value': '91'},
#   {'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_name': 'NORTH DAKOTA',
#    'state_ansi': '38',
#    'source_desc': 'SURVEY',
#    'location_desc': 'NORTH DAKOTA',
#    'state_alpha': 'ND',
#    'Value': '83',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'load_time': '2012-01-01 00:00:00',
#    'country_code': '9000',
#    'state_fips_code': '38',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'congr_district_code': '',
#    'unit_desc': 'CENTS / LB',
#    'week_ending': '',
#    'begin_code': '00',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'CV (%)': '',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'end_code': '00',
#    'county_name': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'watershed_code': '00000000',
#    'country_name': 'UNITED STATES',
#    'county_code': '',
#    'zip_5': '',
#    'agg_level_desc': 'STATE',
#    'group_desc': 'SPECIALTY',
#    'freq_desc': 'ANNUAL',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'region_desc': '',
#    'commodity_desc': 'HONEY',
#    'asd_desc': '',
#    'year': 2005,
#    'county_ansi': '',
#    'domaincat_desc': 'NOT SPECIFIED'},
#   {'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': '',
#    'commodity_desc': 'HONEY',
#    'year': 2004,
#    'asd_desc': '',
#    'region_desc': '',
#    'freq_desc': 'ANNUAL',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'group_desc': 'SPECIALTY',
#    'zip_5': '',
#    'agg_level_desc': 'STATE',
#    'county_code': '',
#    'watershed_code': '00000000',
#    'country_name': 'UNITED STATES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'county_name': '',
#    'end_code': '00',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'CV (%)': '',
#    'begin_code': '00',
#    'week_ending': '',
#    'congr_district_code': '',
#    'unit_desc': 'CENTS / LB',
#    'watershed_desc': '',
#    'state_fips_code': '38',
#    'reference_period_desc': 'MARKETING YEAR',
#    'country_code': '9000',
#    'load_time': '2012-01-01 00:00:00',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'Value': '105',
#    'state_alpha': 'ND',
#    'location_desc': 'NORTH DAKOTA',
#    'state_name': 'NORTH DAKOTA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_ansi': '38',
#    'source_desc': 'SURVEY'},
#   {'zip_5': '',
#    'agg_level_desc': 'STATE',
#    'county_code': '',
#    'watershed_code': '00000000',
#    'country_name': 'UNITED STATES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'county_name': '',
#    'end_code': '00',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': '',
#    'commodity_desc': 'HONEY',
#    'asd_desc': '',
#    'year': 2003,
#    'region_desc': '',
#    'freq_desc': 'ANNUAL',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'group_desc': 'SPECIALTY',
#    'Value': '136',
#    'state_alpha': 'ND',
#    'location_desc': 'NORTH DAKOTA',
#    'state_name': 'NORTH DAKOTA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'source_desc': 'SURVEY',
#    'state_ansi': '38',
#    'domain_desc': 'TOTAL',
#    'asd_code': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'CV (%)': '',
#    'begin_code': '00',
#    'week_ending': '',
#    'congr_district_code': '',
#    'unit_desc': 'CENTS / LB',
#    'state_fips_code': '38',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'load_time': '2012-01-01 00:00:00',
#    'country_code': '9000',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES'},
#   {'end_code': '00',
#    'county_name': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'watershed_code': '00000000',
#    'country_name': 'UNITED STATES',
#    'county_code': '',
#    'zip_5': '',
#    'agg_level_desc': 'STATE',
#    'group_desc': 'SPECIALTY',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'freq_desc': 'ANNUAL',
#    'region_desc': '',
#    'commodity_desc': 'HONEY',
#    'asd_desc': '',
#    'year': 2002,
#    'county_ansi': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'state_name': 'NORTH DAKOTA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_ansi': '38',
#    'source_desc': 'SURVEY',
#    'state_alpha': 'ND',
#    'location_desc': 'NORTH DAKOTA',
#    'Value': '146',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'load_time': '2012-01-01 00:00:00',
#    'country_code': '9000',
#    'state_fips_code': '38',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'unit_desc': 'CENTS / LB',
#    'congr_district_code': '',
#    'week_ending': '',
#    'begin_code': '00',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'CV (%)': '',
#    'asd_code': '',
#    'domain_desc': 'TOTAL'},
#   {'county_ansi': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'group_desc': 'SPECIALTY',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'freq_desc': 'ANNUAL',
#    'region_desc': '',
#    'commodity_desc': 'HONEY',
#    'year': 2001,
#    'asd_desc': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'watershed_code': '00000000',
#    'country_name': 'UNITED STATES',
#    'county_code': '',
#    'zip_5': '',
#    'agg_level_desc': 'STATE',
#    'end_code': '00',
#    'county_name': '',
#    'week_ending': '',
#    'begin_code': '00',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'CV (%)': '',
#    'domain_desc': 'TOTAL',
#    'asd_code': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'load_time': '2012-01-01 00:00:00',
#    'country_code': '9000',
#    'state_fips_code': '38',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'unit_desc': 'CENTS / LB',
#    'congr_district_code': '',
#    'Value': '69',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_name': 'NORTH DAKOTA',
#    'source_desc': 'SURVEY',
#    'state_ansi': '38',
#    'state_alpha': 'ND',
#    'location_desc': 'NORTH DAKOTA'},
#   {'group_desc': 'SPECIALTY',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'freq_desc': 'ANNUAL',
#    'region_desc': '',
#    'commodity_desc': 'HONEY',
#    'year': 2000,
#    'asd_desc': '',
#    'county_ansi': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'end_code': '00',
#    'county_name': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'watershed_code': '00000000',
#    'country_name': 'UNITED STATES',
#    'county_code': '',
#    'zip_5': '',
#    'agg_level_desc': 'STATE',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'load_time': '2012-01-01 00:00:00',
#    'country_code': '9000',
#    'state_fips_code': '38',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'unit_desc': 'CENTS / LB',
#    'congr_district_code': '',
#    'week_ending': '',
#    'begin_code': '00',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'CV (%)': '',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_name': 'NORTH DAKOTA',
#    'source_desc': 'SURVEY',
#    'state_ansi': '38',
#    'state_alpha': 'ND',
#    'location_desc': 'NORTH DAKOTA',
#    'Value': '57'},
#   {'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': '',
#    'freq_desc': 'ANNUAL',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'group_desc': 'SPECIALTY',
#    'asd_desc': '',
#    'year': 1999,
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'country_name': 'UNITED STATES',
#    'watershed_code': '00000000',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'county_code': '',
#    'county_name': '',
#    'end_code': '00',
#    'begin_code': '00',
#    'week_ending': '',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'CV (%)': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'load_time': '2012-01-01 00:00:00',
#    'country_code': '9000',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'congr_district_code': '',
#    'unit_desc': 'CENTS / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'state_fips_code': '38',
#    'Value': '59',
#    'source_desc': 'SURVEY',
#    'state_ansi': '38',
#    'state_name': 'NORTH DAKOTA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'location_desc': 'NORTH DAKOTA',
#    'state_alpha': 'ND'},
#   {'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'country_name': 'UNITED STATES',
#    'watershed_code': '00000000',
#    'county_code': '',
#    'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'end_code': '00',
#    'county_name': '',
#    'county_ansi': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'group_desc': 'SPECIALTY',
#    'freq_desc': 'ANNUAL',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'region_desc': '',
#    'asd_desc': '',
#    'year': 1998,
#    'commodity_desc': 'HONEY',
#    'Value': '63',
#    'state_ansi': '38',
#    'source_desc': 'SURVEY',
#    'state_name': 'NORTH DAKOTA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_alpha': 'ND',
#    'location_desc': 'NORTH DAKOTA',
#    'week_ending': '',
#    'begin_code': '00',
#    'CV (%)': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'country_code': '9000',
#    'load_time': '2012-01-01 00:00:00',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'state_fips_code': '38',
#    'congr_district_code': '',
#    'unit_desc': 'CENTS / LB'},
#   {'domaincat_desc': 'NOT SPECIFIED',
#    'county_ansi': '',
#    'commodity_desc': 'HONEY',
#    'year': 1997,
#    'asd_desc': '',
#    'region_desc': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'freq_desc': 'ANNUAL',
#    'group_desc': 'SPECIALTY',
#    'zip_5': '',
#    'agg_level_desc': 'STATE',
#    'county_code': '',
#    'watershed_code': '00000000',
#    'country_name': 'UNITED STATES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'county_name': '',
#    'end_code': '00',
#    'domain_desc': 'TOTAL',
#    'asd_code': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'CV (%)': '',
#    'begin_code': '00',
#    'week_ending': '',
#    'unit_desc': 'CENTS / LB',
#    'congr_district_code': '',
#    'watershed_desc': '',
#    'state_fips_code': '38',
#    'reference_period_desc': 'MARKETING YEAR',
#    'load_time': '2012-01-01 00:00:00',
#    'country_code': '9000',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'Value': '74',
#    'state_alpha': 'ND',
#    'location_desc': 'NORTH DAKOTA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_name': 'NORTH DAKOTA',
#    'state_ansi': '38',
#    'source_desc': 'SURVEY'},
#   ...]}

# %%
len(new_usda_list)
# Out:
# 21642

# %%
#Modified old code to make it simple. 
new_usda_list=usda_data['data']

# %%
#created DataFrame by passing in the list
usda_df=pd.DataFrame(new_usda_list)
usda_df
# Out:
#       county_name end_code agg_level_desc zip_5 county_code   country_name  \
# 0                       00          STATE                    UNITED STATES
# 1                       00          STATE                    UNITED STATES
# 2                       00          STATE                    UNITED STATES
# 3                       00          STATE                    UNITED STATES
# 4                       00          STATE                    UNITED STATES
# ...           ...      ...            ...   ...         ...            ...
# 21637                   12          STATE                    UNITED STATES
# 21638                   03          STATE                    UNITED STATES
# 21639                   06          STATE                    UNITED STATES
# 21640                   09          STATE                    UNITED STATES
# 21641                   12          STATE                    UNITED STATES
#
#       watershed_code    class_desc         sector_desc  year  ...  \
# 0           00000000   ALL CLASSES  ANIMALS & PRODUCTS  2020  ...
# 1           00000000   ALL CLASSES  ANIMALS & PRODUCTS  2019  ...
# 2           00000000   ALL CLASSES  ANIMALS & PRODUCTS  2018  ...
# 3           00000000   ALL CLASSES  ANIMALS & PRODUCTS  2020  ...
# 4           00000000   ALL CLASSES  ANIMALS & PRODUCTS  2019  ...
# ...              ...           ...                 ...   ...  ...
# 21637       00000000  BEE COLONIES  ANIMALS & PRODUCTS  2016  ...
# 21638       00000000  BEE COLONIES  ANIMALS & PRODUCTS  2015  ...
# 21639       00000000  BEE COLONIES  ANIMALS & PRODUCTS  2015  ...
# 21640       00000000  BEE COLONIES  ANIMALS & PRODUCTS  2015  ...
# 21641       00000000  BEE COLONIES  ANIMALS & PRODUCTS  2015  ...
#
#       watershed_desc country_code            load_time  \
# 0                            9000  2021-03-18 15:00:29
# 1                            9000  2021-03-18 15:00:29
# 2                            9000  2020-03-19 15:06:59
# 3                            9000  2021-03-18 15:00:29
# 4                            9000  2021-03-18 15:00:29
# ...              ...          ...                  ...
# 21637                        9000  2017-08-01 15:00:29
# 21638                        9000  2016-05-12 15:09:03
# 21639                        9000  2016-05-12 15:09:03
# 21640                        9000  2016-05-12 15:09:03
# 21641                        9000  2016-05-12 15:09:03
#
#               util_practice_desc asd_code domain_desc CV (%)  \
# 0      ALL UTILIZATION PRACTICES                TOTAL
# 1      ALL UTILIZATION PRACTICES                TOTAL
# 2      ALL UTILIZATION PRACTICES                TOTAL
# 3      ALL UTILIZATION PRACTICES                TOTAL
# 4      ALL UTILIZATION PRACTICES                TOTAL
# ...                          ...      ...         ...    ...
# 21637  ALL UTILIZATION PRACTICES                TOTAL
# 21638  ALL UTILIZATION PRACTICES                TOTAL
# 21639  ALL UTILIZATION PRACTICES                TOTAL
# 21640  ALL UTILIZATION PRACTICES                TOTAL
# 21641  ALL UTILIZATION PRACTICES                TOTAL
#
#       statisticcat_desc begin_code week_ending
# 0        PRICE RECEIVED         00
# 1        PRICE RECEIVED         00
# 2        PRICE RECEIVED         00
# 3        PRICE RECEIVED         00
# 4        PRICE RECEIVED         00
# ...                 ...        ...         ...
# 21637         INVENTORY         10
# 21638         INVENTORY         01
# 21639         INVENTORY         04
# 21640         INVENTORY         07
# 21641         INVENTORY         10
#
# [21642 rows x 39 columns]

# %%
usda_df.columns
# Out:
# Index(['county_name', 'end_code', 'agg_level_desc', 'zip_5', 'county_code',
#        'country_name', 'watershed_code', 'class_desc', 'sector_desc', 'year',
#        'asd_desc', 'commodity_desc', 'region_desc', 'short_desc', 'freq_desc',
#        'group_desc', 'domaincat_desc', 'county_ansi', 'location_desc',
#        'state_alpha', 'state_ansi', 'source_desc', 'prodn_practice_desc',
#        'state_name', 'Value', 'congr_district_code', 'unit_desc',
#        'reference_period_desc', 'state_fips_code', 'watershed_desc',
#        'country_code', 'load_time', 'util_practice_desc', 'asd_code',
#        'domain_desc', 'CV (%)', 'statisticcat_desc', 'begin_code',
#        'week_ending'],
#       dtype='object')

# %%
#Selected required columns (23 columns) in the process of data clean-up
usda_mod_df=usda_df[['group_desc','reference_period_desc', 'load_time', 'country_name', 'source_desc', 'country_code', 'location_desc', 'state_alpha', 'prodn_practice_desc', 'commodity_desc', 'sector_desc', 'agg_level_desc', 'class_desc', 'year',  'state_name', 'Value', 'short_desc', 'domaincat_desc', 'state_ansi', 'domain_desc', 'statisticcat_desc', 'util_practice_desc', 'freq_desc']]
usda_mod_df.head(1)
# Out:
#   group_desc reference_period_desc            load_time   country_name  \
# 0  SPECIALTY        MARKETING YEAR  2021-03-18 15:00:29  UNITED STATES
#
#   source_desc country_code location_desc state_alpha  \
# 0      SURVEY         9000       ALABAMA          AL
#
#         prodn_practice_desc commodity_desc  ...  year state_name Value  \
# 0  ALL PRODUCTION PRACTICES          HONEY  ...  2020    ALABAMA  5.43
#
#                                    short_desc domaincat_desc state_ansi  \
# 0  HONEY - PRICE RECEIVED, MEASURED IN $ / LB  NOT SPECIFIED         01
#
#   domain_desc statisticcat_desc         util_practice_desc freq_desc
# 0       TOTAL    PRICE RECEIVED  ALL UTILIZATION PRACTICES    ANNUAL
#
# [1 rows x 23 columns]

# %%
# Extracted data only for Colony collapse disorder(CCD) for 2020 year
usda_collapse_df = usda_mod_df[usda_mod_df['short_desc'].str.contains("COLONY COLLAPSE DISORDER")]
usda_collapse_df1 = usda_collapse_df[usda_collapse_df['year']==2020]
usda_collapse_df1
#92 rows with 23 columns
# Out:
#       group_desc reference_period_desc            load_time   country_name  \
# 17562  SPECIALTY          JAN THRU MAR  2020-08-03 15:00:16  UNITED STATES
# 17563  SPECIALTY          APR THRU JUN  2020-08-03 15:00:16  UNITED STATES
# 17567  SPECIALTY          JAN THRU MAR  2020-08-03 15:00:16  UNITED STATES
# 17568  SPECIALTY          APR THRU JUN  2020-08-03 15:00:16  UNITED STATES
# 17572  SPECIALTY          JAN THRU MAR  2020-08-03 15:00:16  UNITED STATES
# ...          ...                   ...                  ...            ...
# 17773  SPECIALTY          APR THRU JUN  2020-08-03 15:00:16  UNITED STATES
# 17777  SPECIALTY          JAN THRU MAR  2020-08-03 15:00:16  UNITED STATES
# 17778  SPECIALTY          APR THRU JUN  2020-08-03 15:00:16  UNITED STATES
# 17782  SPECIALTY          JAN THRU MAR  2020-08-03 15:00:16  UNITED STATES
# 17783  SPECIALTY          APR THRU JUN  2020-08-03 15:00:16  UNITED STATES
#
#       source_desc country_code  location_desc state_alpha  \
# 17562      SURVEY         9000        ALABAMA          AL
# 17563      SURVEY         9000        ALABAMA          AL
# 17567      SURVEY         9000        ARIZONA          AZ
# 17568      SURVEY         9000        ARIZONA          AZ
# 17572      SURVEY         9000       ARKANSAS          AR
# ...           ...          ...            ...         ...
# 17773      SURVEY         9000  WEST VIRGINIA          WV
# 17777      SURVEY         9000      WISCONSIN          WI
# 17778      SURVEY         9000      WISCONSIN          WI
# 17782      SURVEY         9000        WYOMING          WY
# 17783      SURVEY         9000        WYOMING          WY
#
#             prodn_practice_desc commodity_desc  ...  year     state_name  \
# 17562  ALL PRODUCTION PRACTICES          HONEY  ...  2020        ALABAMA
# 17563  ALL PRODUCTION PRACTICES          HONEY  ...  2020        ALABAMA
# 17567  ALL PRODUCTION PRACTICES          HONEY  ...  2020        ARIZONA
# 17568  ALL PRODUCTION PRACTICES          HONEY  ...  2020        ARIZONA
# 17572  ALL PRODUCTION PRACTICES          HONEY  ...  2020       ARKANSAS
# ...                         ...            ...  ...   ...            ...
# 17773  ALL PRODUCTION PRACTICES          HONEY  ...  2020  WEST VIRGINIA
# 17777  ALL PRODUCTION PRACTICES          HONEY  ...  2020      WISCONSIN
# 17778  ALL PRODUCTION PRACTICES          HONEY  ...  2020      WISCONSIN
# 17782  ALL PRODUCTION PRACTICES          HONEY  ...  2020        WYOMING
# 17783  ALL PRODUCTION PRACTICES          HONEY  ...  2020        WYOMING
#
#        Value                                         short_desc  \
# 17562     70  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17563    410  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17567  4,300  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17568    170  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17572    390  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# ...      ...                                                ...
# 17773    130  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17777  1,600  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17778     90  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17782  1,500  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17783    500  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
#
#       domaincat_desc state_ansi domain_desc               statisticcat_desc  \
# 17562  NOT SPECIFIED         01       TOTAL  LOSS, COLONY COLLAPSE DISORDER
# 17563  NOT SPECIFIED         01       TOTAL  LOSS, COLONY COLLAPSE DISORDER
# 17567  NOT SPECIFIED         04       TOTAL  LOSS, COLONY COLLAPSE DISORDER
# 17568  NOT SPECIFIED         04       TOTAL  LOSS, COLONY COLLAPSE DISORDER
# 17572  NOT SPECIFIED         05       TOTAL  LOSS, COLONY COLLAPSE DISORDER
# ...              ...        ...         ...                             ...
# 17773  NOT SPECIFIED         54       TOTAL  LOSS, COLONY COLLAPSE DISORDER
# 17777  NOT SPECIFIED         55       TOTAL  LOSS, COLONY COLLAPSE DISORDER
# 17778  NOT SPECIFIED         55       TOTAL  LOSS, COLONY COLLAPSE DISORDER
# 17782  NOT SPECIFIED         56       TOTAL  LOSS, COLONY COLLAPSE DISORDER
# 17783  NOT SPECIFIED         56       TOTAL  LOSS, COLONY COLLAPSE DISORDER
#
#               util_practice_desc freq_desc
# 17562  ALL UTILIZATION PRACTICES   MONTHLY
# 17563  ALL UTILIZATION PRACTICES   MONTHLY
# 17567  ALL UTILIZATION PRACTICES   MONTHLY
# 17568  ALL UTILIZATION PRACTICES   MONTHLY
# 17572  ALL UTILIZATION PRACTICES   MONTHLY
# ...                          ...       ...
# 17773  ALL UTILIZATION PRACTICES   MONTHLY
# 17777  ALL UTILIZATION PRACTICES   MONTHLY
# 17778  ALL UTILIZATION PRACTICES   MONTHLY
# 17782  ALL UTILIZATION PRACTICES   MONTHLY
# 17783  ALL UTILIZATION PRACTICES   MONTHLY
#
# [90 rows x 23 columns]

# %%
#Extracted data only for bees effected through pesticides in 2020
usda_pesticide_df = usda_mod_df[usda_mod_df['short_desc'].str.contains("AFFECTED BY PESTICIDES")]
usda_pesticide_df1 = usda_pesticide_df[usda_pesticide_df['year']==2020]
usda_pesticide_df1
# Out:
#       group_desc reference_period_desc            load_time   country_name  \
# 9322   SPECIALTY          JAN THRU MAR  2020-08-03 15:00:16  UNITED STATES
# 9323   SPECIALTY          APR THRU JUN  2020-08-03 15:00:16  UNITED STATES
# 9343   SPECIALTY          JAN THRU MAR  2020-08-03 15:00:16  UNITED STATES
# 9344   SPECIALTY          APR THRU JUN  2020-08-03 15:00:16  UNITED STATES
# 9364   SPECIALTY          JAN THRU MAR  2020-08-03 15:00:16  UNITED STATES
# ...          ...                   ...                  ...            ...
# 10226  SPECIALTY          APR THRU JUN  2020-08-03 15:00:16  UNITED STATES
# 10246  SPECIALTY          JAN THRU MAR  2020-08-03 15:00:16  UNITED STATES
# 10247  SPECIALTY          APR THRU JUN  2020-08-03 15:00:16  UNITED STATES
# 10267  SPECIALTY          JAN THRU MAR  2020-08-03 15:00:16  UNITED STATES
# 10268  SPECIALTY          APR THRU JUN  2020-08-03 15:00:16  UNITED STATES
#
#       source_desc country_code location_desc state_alpha  \
# 9322       SURVEY         9000       ALABAMA          AL
# 9323       SURVEY         9000       ALABAMA          AL
# 9343       SURVEY         9000       ARIZONA          AZ
# 9344       SURVEY         9000       ARIZONA          AZ
# 9364       SURVEY         9000      ARKANSAS          AR
# ...           ...          ...           ...         ...
# 10226      SURVEY         9000     WISCONSIN          WI
# 10246      SURVEY         9000       WYOMING          WY
# 10247      SURVEY         9000       WYOMING          WY
# 10267      SURVEY         9000  OTHER STATES          OT
# 10268      SURVEY         9000  OTHER STATES          OT
#
#           prodn_practice_desc commodity_desc  ...  year    state_name Value  \
# 9322   AFFECTED BY PESTICIDES          HONEY  ...  2020       ALABAMA   0.1
# 9323   AFFECTED BY PESTICIDES          HONEY  ...  2020       ALABAMA   7.7
# 9343   AFFECTED BY PESTICIDES          HONEY  ...  2020       ARIZONA     0
# 9344   AFFECTED BY PESTICIDES          HONEY  ...  2020       ARIZONA   4.2
# 9364   AFFECTED BY PESTICIDES          HONEY  ...  2020      ARKANSAS   2.6
# ...                       ...            ...  ...   ...           ...   ...
# 10226  AFFECTED BY PESTICIDES          HONEY  ...  2020     WISCONSIN  25.1
# 10246  AFFECTED BY PESTICIDES          HONEY  ...  2020       WYOMING     0
# 10247  AFFECTED BY PESTICIDES          HONEY  ...  2020       WYOMING   1.1
# 10267  AFFECTED BY PESTICIDES          HONEY  ...  2020  OTHER STATES     0
# 10268  AFFECTED BY PESTICIDES          HONEY  ...  2020  OTHER STATES     0
#
#                                               short_desc domaincat_desc  \
# 9322   HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...  NOT SPECIFIED
# 9323   HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...  NOT SPECIFIED
# 9343   HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...  NOT SPECIFIED
# 9344   HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...  NOT SPECIFIED
# 9364   HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...  NOT SPECIFIED
# ...                                                  ...            ...
# 10226  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...  NOT SPECIFIED
# 10246  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...  NOT SPECIFIED
# 10247  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...  NOT SPECIFIED
# 10267  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...  NOT SPECIFIED
# 10268  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...  NOT SPECIFIED
#
#       state_ansi domain_desc statisticcat_desc         util_practice_desc  \
# 9322          01       TOTAL         INVENTORY  ALL UTILIZATION PRACTICES
# 9323          01       TOTAL         INVENTORY  ALL UTILIZATION PRACTICES
# 9343          04       TOTAL         INVENTORY  ALL UTILIZATION PRACTICES
# 9344          04       TOTAL         INVENTORY  ALL UTILIZATION PRACTICES
# 9364          05       TOTAL         INVENTORY  ALL UTILIZATION PRACTICES
# ...          ...         ...               ...                        ...
# 10226         55       TOTAL         INVENTORY  ALL UTILIZATION PRACTICES
# 10246         56       TOTAL         INVENTORY  ALL UTILIZATION PRACTICES
# 10247         56       TOTAL         INVENTORY  ALL UTILIZATION PRACTICES
# 10267                  TOTAL         INVENTORY  ALL UTILIZATION PRACTICES
# 10268                  TOTAL         INVENTORY  ALL UTILIZATION PRACTICES
#
#       freq_desc
# 9322    MONTHLY
# 9323    MONTHLY
# 9343    MONTHLY
# 9344    MONTHLY
# 9364    MONTHLY
# ...         ...
# 10226   MONTHLY
# 10246   MONTHLY
# 10247   MONTHLY
# 10267   MONTHLY
# 10268   MONTHLY
#
# [92 rows x 23 columns]

# %%
#Original dataframe with selected columns (21642 rows, 8 columns)
usda_mod_df2=usda_mod_df[['reference_period_desc', 'source_desc', 'location_desc', 'sector_desc', 'year', 'Value', 'short_desc', 'statisticcat_desc']]
usda_mod_df2
# Out:
#       reference_period_desc source_desc location_desc         sector_desc  \
# 0            MARKETING YEAR      SURVEY       ALABAMA  ANIMALS & PRODUCTS
# 1            MARKETING YEAR      SURVEY       ALABAMA  ANIMALS & PRODUCTS
# 2            MARKETING YEAR      SURVEY       ALABAMA  ANIMALS & PRODUCTS
# 3            MARKETING YEAR      SURVEY       ARIZONA  ANIMALS & PRODUCTS
# 4            MARKETING YEAR      SURVEY       ARIZONA  ANIMALS & PRODUCTS
# ...                     ...         ...           ...                 ...
# 21637          OCT THRU DEC      SURVEY  OTHER STATES  ANIMALS & PRODUCTS
# 21638          JAN THRU MAR      SURVEY  OTHER STATES  ANIMALS & PRODUCTS
# 21639          APR THRU JUN      SURVEY  OTHER STATES  ANIMALS & PRODUCTS
# 21640          JUL THRU SEP      SURVEY  OTHER STATES  ANIMALS & PRODUCTS
# 21641          OCT THRU DEC      SURVEY  OTHER STATES  ANIMALS & PRODUCTS
#
#        year Value                                         short_desc  \
# 0      2020  5.43         HONEY - PRICE RECEIVED, MEASURED IN $ / LB
# 1      2019  3.38         HONEY - PRICE RECEIVED, MEASURED IN $ / LB
# 2      2018  3.72         HONEY - PRICE RECEIVED, MEASURED IN $ / LB
# 3      2020  2.18         HONEY - PRICE RECEIVED, MEASURED IN $ / LB
# 4      2019  2.04         HONEY - PRICE RECEIVED, MEASURED IN $ / LB
# ...     ...   ...                                                ...
# 21637  2016     0  HONEY, BEE COLONIES, RENOVATED - INVENTORY, ME...
# 21638  2015     2  HONEY, BEE COLONIES, RENOVATED - INVENTORY, ME...
# 21639  2015    18  HONEY, BEE COLONIES, RENOVATED - INVENTORY, ME...
# 21640  2015     6  HONEY, BEE COLONIES, RENOVATED - INVENTORY, ME...
# 21641  2015     0  HONEY, BEE COLONIES, RENOVATED - INVENTORY, ME...
#
#       statisticcat_desc
# 0        PRICE RECEIVED
# 1        PRICE RECEIVED
# 2        PRICE RECEIVED
# 3        PRICE RECEIVED
# 4        PRICE RECEIVED
# ...                 ...
# 21637         INVENTORY
# 21638         INVENTORY
# 21639         INVENTORY
# 21640         INVENTORY
# 21641         INVENTORY
#
# [21642 rows x 8 columns]

# %%
#Extracted data with CCD for 2020 year (90 rows, 8 columns)
usda_collapse_df2 = usda_mod_df2[usda_mod_df2['short_desc'].str.contains("COLONY COLLAPSE DISORDER")]
usda_collapse_2020 = usda_collapse_df2[usda_collapse_df2['year']==2020]
usda_collapse_2020
# Out:
#       reference_period_desc source_desc  location_desc         sector_desc  \
# 17562          JAN THRU MAR      SURVEY        ALABAMA  ANIMALS & PRODUCTS
# 17563          APR THRU JUN      SURVEY        ALABAMA  ANIMALS & PRODUCTS
# 17567          JAN THRU MAR      SURVEY        ARIZONA  ANIMALS & PRODUCTS
# 17568          APR THRU JUN      SURVEY        ARIZONA  ANIMALS & PRODUCTS
# 17572          JAN THRU MAR      SURVEY       ARKANSAS  ANIMALS & PRODUCTS
# ...                     ...         ...            ...                 ...
# 17773          APR THRU JUN      SURVEY  WEST VIRGINIA  ANIMALS & PRODUCTS
# 17777          JAN THRU MAR      SURVEY      WISCONSIN  ANIMALS & PRODUCTS
# 17778          APR THRU JUN      SURVEY      WISCONSIN  ANIMALS & PRODUCTS
# 17782          JAN THRU MAR      SURVEY        WYOMING  ANIMALS & PRODUCTS
# 17783          APR THRU JUN      SURVEY        WYOMING  ANIMALS & PRODUCTS
#
#        year  Value                                         short_desc  \
# 17562  2020     70  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17563  2020    410  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17567  2020  4,300  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17568  2020    170  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17572  2020    390  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# ...     ...    ...                                                ...
# 17773  2020    130  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17777  2020  1,600  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17778  2020     90  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17782  2020  1,500  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17783  2020    500  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
#
#                     statisticcat_desc
# 17562  LOSS, COLONY COLLAPSE DISORDER
# 17563  LOSS, COLONY COLLAPSE DISORDER
# 17567  LOSS, COLONY COLLAPSE DISORDER
# 17568  LOSS, COLONY COLLAPSE DISORDER
# 17572  LOSS, COLONY COLLAPSE DISORDER
# ...                               ...
# 17773  LOSS, COLONY COLLAPSE DISORDER
# 17777  LOSS, COLONY COLLAPSE DISORDER
# 17778  LOSS, COLONY COLLAPSE DISORDER
# 17782  LOSS, COLONY COLLAPSE DISORDER
# 17783  LOSS, COLONY COLLAPSE DISORDER
#
# [90 rows x 8 columns]

# %%
#Removed "," from value columns
usda_collapse_2020['Value']=usda_collapse_2020['Value'].str.replace(',','')
usda_collapse_2020
# Out:
# <ipython-input-12-fb2e371b2bd2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_collapse_2020['Value']=usda_collapse_2020['Value'].str.replace(',','')
#       reference_period_desc source_desc  location_desc         sector_desc  \
# 17562          JAN THRU MAR      SURVEY        ALABAMA  ANIMALS & PRODUCTS
# 17563          APR THRU JUN      SURVEY        ALABAMA  ANIMALS & PRODUCTS
# 17567          JAN THRU MAR      SURVEY        ARIZONA  ANIMALS & PRODUCTS
# 17568          APR THRU JUN      SURVEY        ARIZONA  ANIMALS & PRODUCTS
# 17572          JAN THRU MAR      SURVEY       ARKANSAS  ANIMALS & PRODUCTS
# ...                     ...         ...            ...                 ...
# 17773          APR THRU JUN      SURVEY  WEST VIRGINIA  ANIMALS & PRODUCTS
# 17777          JAN THRU MAR      SURVEY      WISCONSIN  ANIMALS & PRODUCTS
# 17778          APR THRU JUN      SURVEY      WISCONSIN  ANIMALS & PRODUCTS
# 17782          JAN THRU MAR      SURVEY        WYOMING  ANIMALS & PRODUCTS
# 17783          APR THRU JUN      SURVEY        WYOMING  ANIMALS & PRODUCTS
#
#        year Value                                         short_desc  \
# 17562  2020    70  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17563  2020   410  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17567  2020  4300  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17568  2020   170  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17572  2020   390  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# ...     ...   ...                                                ...
# 17773  2020   130  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17777  2020  1600  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17778  2020    90  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17782  2020  1500  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17783  2020   500  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
#
#                     statisticcat_desc
# 17562  LOSS, COLONY COLLAPSE DISORDER
# 17563  LOSS, COLONY COLLAPSE DISORDER
# 17567  LOSS, COLONY COLLAPSE DISORDER
# 17568  LOSS, COLONY COLLAPSE DISORDER
# 17572  LOSS, COLONY COLLAPSE DISORDER
# ...                               ...
# 17773  LOSS, COLONY COLLAPSE DISORDER
# 17777  LOSS, COLONY COLLAPSE DISORDER
# 17778  LOSS, COLONY COLLAPSE DISORDER
# 17782  LOSS, COLONY COLLAPSE DISORDER
# 17783  LOSS, COLONY COLLAPSE DISORDER
#
# [90 rows x 8 columns]

# %%
#converted value column in CCD 2020 from str to float
usda_collapse_2020['Value'] = usda_collapse_2020['Value'].astype(float)
usda_collapse_2020['Value'].dtype
# Out:
# <ipython-input-13-613c23db0dd8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_collapse_2020['Value'] = usda_collapse_2020['Value'].astype(float)
# dtype('float64')

# %%
usda_collapse_2020.Value.sum()
# Out:
# 161060.0

# %%
#imported CCD 2020 data to local space
usda_collapse_2020.to_csv(r'C:\Users\watso\Documents\Data_Science_Bootcamp\exploratory_data_analysis_project.csv')

# %%
#Extracted data for honey bee loss with pesticides for 2020
usda_pesticide_df2 = usda_mod_df2[usda_mod_df2['short_desc'].str.contains("AFFECTED BY PESTICIDES")]
usda_pesticide_2020 = usda_pesticide_df2[usda_pesticide_df2['year']==2020]
#converted value column from string to float
usda_pesticide_2020['Value']=pd.to_numeric(usda_pesticide_2020['Value'], errors='coerce')
usda_pesticide_2020['Value'].dtype
#92 rows, 8 columns
# Out:
# <ipython-input-16-5adbedc917ed>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_pesticide_2020['Value']=pd.to_numeric(usda_pesticide_2020['Value'], errors='coerce')
# dtype('float64')

# %% [markdown]
# #imported pesticides 2020 data to local space as csv
# usda_pesticide_2020.to_csv(r'/Users/trimpu/Documents/exploratory_data_analysis_project.csv')

# %%
#usda_pesticide_2020.iloc[20][5], iloc[69][5], iloc[86][5] . Changed these values to 0. 
usda_pesticide_2020['Value'] = usda_pesticide_2020['Value'].replace(['                 (Z)'], '0')
usda_pesticide_2020
#usda_pesticide_2020['Value']=usda_pesticide_2020['Value'].str.replace(' ','')
#usda_pesticide_2020['Value'].sum()
# Out:
# <ipython-input-17-097bd01d777f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_pesticide_2020['Value'] = usda_pesticide_2020['Value'].replace(['                 (Z)'], '0')
#       reference_period_desc source_desc location_desc         sector_desc  \
# 9322           JAN THRU MAR      SURVEY       ALABAMA  ANIMALS & PRODUCTS
# 9323           APR THRU JUN      SURVEY       ALABAMA  ANIMALS & PRODUCTS
# 9343           JAN THRU MAR      SURVEY       ARIZONA  ANIMALS & PRODUCTS
# 9344           APR THRU JUN      SURVEY       ARIZONA  ANIMALS & PRODUCTS
# 9364           JAN THRU MAR      SURVEY      ARKANSAS  ANIMALS & PRODUCTS
# ...                     ...         ...           ...                 ...
# 10226          APR THRU JUN      SURVEY     WISCONSIN  ANIMALS & PRODUCTS
# 10246          JAN THRU MAR      SURVEY       WYOMING  ANIMALS & PRODUCTS
# 10247          APR THRU JUN      SURVEY       WYOMING  ANIMALS & PRODUCTS
# 10267          JAN THRU MAR      SURVEY  OTHER STATES  ANIMALS & PRODUCTS
# 10268          APR THRU JUN      SURVEY  OTHER STATES  ANIMALS & PRODUCTS
#
#        year  Value                                         short_desc  \
# 9322   2020    0.1  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...
# 9323   2020    7.7  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...
# 9343   2020    0.0  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...
# 9344   2020    4.2  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...
# 9364   2020    2.6  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...
# ...     ...    ...                                                ...
# 10226  2020   25.1  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...
# 10246  2020    0.0  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...
# 10247  2020    1.1  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...
# 10267  2020    0.0  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...
# 10268  2020    0.0  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...
#
#       statisticcat_desc
# 9322          INVENTORY
# 9323          INVENTORY
# 9343          INVENTORY
# 9344          INVENTORY
# 9364          INVENTORY
# ...                 ...
# 10226         INVENTORY
# 10246         INVENTORY
# 10247         INVENTORY
# 10267         INVENTORY
# 10268         INVENTORY
#
# [92 rows x 8 columns]

# %%
# Applying each row in value column with float datatype. 
usda_pesticide_2020['Value'].apply(lambda x: float(x))
usda_pesticide_2020
# Out:
#       reference_period_desc source_desc location_desc         sector_desc  \
# 9322           JAN THRU MAR      SURVEY       ALABAMA  ANIMALS & PRODUCTS
# 9323           APR THRU JUN      SURVEY       ALABAMA  ANIMALS & PRODUCTS
# 9343           JAN THRU MAR      SURVEY       ARIZONA  ANIMALS & PRODUCTS
# 9344           APR THRU JUN      SURVEY       ARIZONA  ANIMALS & PRODUCTS
# 9364           JAN THRU MAR      SURVEY      ARKANSAS  ANIMALS & PRODUCTS
# ...                     ...         ...           ...                 ...
# 10226          APR THRU JUN      SURVEY     WISCONSIN  ANIMALS & PRODUCTS
# 10246          JAN THRU MAR      SURVEY       WYOMING  ANIMALS & PRODUCTS
# 10247          APR THRU JUN      SURVEY       WYOMING  ANIMALS & PRODUCTS
# 10267          JAN THRU MAR      SURVEY  OTHER STATES  ANIMALS & PRODUCTS
# 10268          APR THRU JUN      SURVEY  OTHER STATES  ANIMALS & PRODUCTS
#
#        year  Value                                         short_desc  \
# 9322   2020    0.1  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...
# 9323   2020    7.7  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...
# 9343   2020    0.0  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...
# 9344   2020    4.2  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...
# 9364   2020    2.6  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...
# ...     ...    ...                                                ...
# 10226  2020   25.1  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...
# 10246  2020    0.0  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...
# 10247  2020    1.1  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...
# 10267  2020    0.0  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...
# 10268  2020    0.0  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...
#
#       statisticcat_desc
# 9322          INVENTORY
# 9323          INVENTORY
# 9343          INVENTORY
# 9344          INVENTORY
# 9364          INVENTORY
# ...                 ...
# 10226         INVENTORY
# 10246         INVENTORY
# 10247         INVENTORY
# 10267         INVENTORY
# 10268         INVENTORY
#
# [92 rows x 8 columns]

# %%
#Fetched inventory with required columns from the original DataFrame. 
usda_inventory_df = usda_mod_df[usda_mod_df['short_desc'].str.contains("INVENTORY, MAX,")]
usda_inventory_df1 = usda_inventory_df[usda_inventory_df['year']==2020]
usda_inventory_df1=usda_inventory_df1[['reference_period_desc','source_desc','location_desc',
                                       'sector_desc','year','Value','short_desc','statisticcat_desc']]
#Renamed value column in inventory dataframe to inventory_value. Inplace=true changes the original dataframe
usda_inventory_df1.rename(columns={'Value':'inventory_value'},inplace=True)
usda_inventory_df1
# Out:
#       reference_period_desc source_desc location_desc         sector_desc  \
# 16596          JAN THRU MAR      SURVEY       ALABAMA  ANIMALS & PRODUCTS
# 16597          APR THRU JUN      SURVEY       ALABAMA  ANIMALS & PRODUCTS
# 16617          JAN THRU MAR      SURVEY       ARIZONA  ANIMALS & PRODUCTS
# 16618          APR THRU JUN      SURVEY       ARIZONA  ANIMALS & PRODUCTS
# 16638          JAN THRU MAR      SURVEY      ARKANSAS  ANIMALS & PRODUCTS
# ...                     ...         ...           ...                 ...
# 17500          APR THRU JUN      SURVEY     WISCONSIN  ANIMALS & PRODUCTS
# 17520          JAN THRU MAR      SURVEY       WYOMING  ANIMALS & PRODUCTS
# 17521          APR THRU JUN      SURVEY       WYOMING  ANIMALS & PRODUCTS
# 17541          JAN THRU MAR      SURVEY  OTHER STATES  ANIMALS & PRODUCTS
# 17542          APR THRU JUN      SURVEY  OTHER STATES  ANIMALS & PRODUCTS
#
#        year inventory_value  \
# 16596  2020           8,000
# 16597  2020           8,500
# 16617  2020          32,000
# 16618  2020          26,000
# 16638  2020          17,500
# ...     ...             ...
# 17500  2020          53,000
# 17520  2020          17,000
# 17521  2020          24,000
# 17541  2020           8,200
# 17542  2020           7,440
#
#                                               short_desc statisticcat_desc
# 16596  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# 16597  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# 16617  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# 16618  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# 16638  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# ...                                                  ...               ...
# 17500  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# 17520  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# 17521  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# 17541  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# 17542  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
#
# [92 rows x 8 columns]

# %%
#imported inventory 2020 data to local space as csv
usda_inventory_df1.to_csv(r'C:\Users\watso\Documents\Data_Science_Bootcamp\exploratory_data_analysis_project\inventory_EDA_project.csv')

# %%
#merged inventory dataframe with pesticides dataframe, so that "value" column in pesticides 
#which is measured in percentage of inventory_value can be calculated.  
inv_pest=pd.merge(usda_inventory_df1,usda_pesticide_2020,how='outer',on=['reference_period_desc','location_desc'])

# %%
inv_pest
# Out:
#    reference_period_desc source_desc_x location_desc       sector_desc_x  \
# 0           JAN THRU MAR        SURVEY       ALABAMA  ANIMALS & PRODUCTS
# 1           APR THRU JUN        SURVEY       ALABAMA  ANIMALS & PRODUCTS
# 2           JAN THRU MAR        SURVEY       ARIZONA  ANIMALS & PRODUCTS
# 3           APR THRU JUN        SURVEY       ARIZONA  ANIMALS & PRODUCTS
# 4           JAN THRU MAR        SURVEY      ARKANSAS  ANIMALS & PRODUCTS
# ..                   ...           ...           ...                 ...
# 87          APR THRU JUN        SURVEY     WISCONSIN  ANIMALS & PRODUCTS
# 88          JAN THRU MAR        SURVEY       WYOMING  ANIMALS & PRODUCTS
# 89          APR THRU JUN        SURVEY       WYOMING  ANIMALS & PRODUCTS
# 90          JAN THRU MAR        SURVEY  OTHER STATES  ANIMALS & PRODUCTS
# 91          APR THRU JUN        SURVEY  OTHER STATES  ANIMALS & PRODUCTS
#
#     year_x  inventory_value  \
# 0     2020           8000.0
# 1     2020           8500.0
# 2     2020          32000.0
# 3     2020          26000.0
# 4     2020          17500.0
# ..     ...              ...
# 87    2020          53000.0
# 88    2020          17000.0
# 89    2020          24000.0
# 90    2020           8200.0
# 91    2020           7440.0
#
#                                          short_desc_x statisticcat_desc_x  \
# 0   HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...      INVENTORY, MAX
# 1   HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...      INVENTORY, MAX
# 2   HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...      INVENTORY, MAX
# 3   HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...      INVENTORY, MAX
# 4   HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...      INVENTORY, MAX
# ..                                                ...                 ...
# 87  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...      INVENTORY, MAX
# 88  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...      INVENTORY, MAX
# 89  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...      INVENTORY, MAX
# 90  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...      INVENTORY, MAX
# 91  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...      INVENTORY, MAX
#
#    source_desc_y       sector_desc_y  year_y  Value  \
# 0         SURVEY  ANIMALS & PRODUCTS    2020    0.1
# 1         SURVEY  ANIMALS & PRODUCTS    2020    7.7
# 2         SURVEY  ANIMALS & PRODUCTS    2020    0.0
# 3         SURVEY  ANIMALS & PRODUCTS    2020    4.2
# 4         SURVEY  ANIMALS & PRODUCTS    2020    2.6
# ..           ...                 ...     ...    ...
# 87        SURVEY  ANIMALS & PRODUCTS    2020   25.1
# 88        SURVEY  ANIMALS & PRODUCTS    2020    0.0
# 89        SURVEY  ANIMALS & PRODUCTS    2020    1.1
# 90        SURVEY  ANIMALS & PRODUCTS    2020    0.0
# 91        SURVEY  ANIMALS & PRODUCTS    2020    0.0
#
#                                          short_desc_y statisticcat_desc_y  \
# 0   HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...           INVENTORY
# 1   HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...           INVENTORY
# 2   HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...           INVENTORY
# 3   HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...           INVENTORY
# 4   HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...           INVENTORY
# ..                                                ...                 ...
# 87  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...           INVENTORY
# 88  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...           INVENTORY
# 89  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...           INVENTORY
# 90  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...           INVENTORY
# 91  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...           INVENTORY
#
#     pest_value
# 0          8.0
# 1        654.5
# 2          0.0
# 3       1092.0
# 4        455.0
# ..         ...
# 87     13303.0
# 88         0.0
# 89       264.0
# 90         0.0
# 91         0.0
#
# [92 rows x 15 columns]

# %%
#Replaced "," with '' in inv_pest['inventory_value'] column. 
inv_pest['inventory_value']=inv_pest['inventory_value'].str.replace(',','')
inv_pest['inventory_value']
#converted to float to make sure all the values are on float datatype. 
inv_pest['inventory_value']=inv_pest['inventory_value'].apply(lambda x: float(x))
inv_pest['inventory_value'].dtype
 
#inv_pest['inventory_value']=pd.to_numeric(inv_pest['inventory_value'], errors='ignore')
#inv_pest['inventory_value']

#usda_pesticide_2020['Value'].apply(lambda x: float(x))
# Out:
# dtype('float64')

# %%
(0.1*8000)/100
# Out:
# 8.0

# %%
#Define a temporary function that takes in 2 values and calculates 
#what percentage of total inventory is effected with pesticides for each record. 
def temp_func(val,inv_val):
    print (inv_val)
    f_val=(val*inv_val)/100
    return f_val

#inv_pest['pest_value'] - a new column is craeted in inv_pest dataframe
inv_pest['pest_value']=inv_pest.apply(lambda x: temp_func(x['Value'],x['inventory_value']), axis=1)
inv_pest
# Out:
# 8000.0
# 8500.0
# 32000.0
# 26000.0
# 17500.0
# 17000.0
# 1710000.0
# 1200000.0
# 16000.0
# 27000.0
# 4100.0
# 4300.0
# 310000.0
# 325000.0
# 121000.0
# 143000.0
# 16000.0
# 15500.0
# 168000.0
# 81000.0
# 13000.0
# 12000.0
# 11500.0
# 12000.0
# 21000.0
# 29000.0
# 7000.0
# 8000.0
# 10500.0
# 11000.0
# 48000.0
# 53000.0
# 1700.0
# 22000.0
# 7500.0
# 8000.0
# 4000.0
# 13500.0
# 65000.0
# 79000.0
# 57000.0
# 126000.0
# 28000.0
# 37000.0
# 8500.0
# 6500.0
# 48000.0
# 120000.0
# 17000.0
# 39000.0
# 7000.0
# 20000.0
# 6000.0
# 6000.0
# 36000.0
# 56000.0
# 23000.0
# 25000.0
# 82000.0
# 395000.0
# 20000.0
# 16500.0
# 19500.0
# 16000.0
# 108000.0
# 95000.0
# 24000.0
# 27000.0
# 16500.0
# 20000.0
# 20000.0
# 205000.0
# 14000.0
# 13500.0
# 340000.0
# 385000.0
# 17000.0
# 31000.0
# 7500.0
# 7000.0
# 7000.0
# 8000.0
# 74000.0
# 114000.0
# 8000.0
# 7500.0
# 26000.0
# 53000.0
# 17000.0
# 24000.0
# 8200.0
# 7440.0
#    reference_period_desc source_desc_x location_desc       sector_desc_x  \
# 0           JAN THRU MAR        SURVEY       ALABAMA  ANIMALS & PRODUCTS
# 1           APR THRU JUN        SURVEY       ALABAMA  ANIMALS & PRODUCTS
# 2           JAN THRU MAR        SURVEY       ARIZONA  ANIMALS & PRODUCTS
# 3           APR THRU JUN        SURVEY       ARIZONA  ANIMALS & PRODUCTS
# 4           JAN THRU MAR        SURVEY      ARKANSAS  ANIMALS & PRODUCTS
# ..                   ...           ...           ...                 ...
# 87          APR THRU JUN        SURVEY     WISCONSIN  ANIMALS & PRODUCTS
# 88          JAN THRU MAR        SURVEY       WYOMING  ANIMALS & PRODUCTS
# 89          APR THRU JUN        SURVEY       WYOMING  ANIMALS & PRODUCTS
# 90          JAN THRU MAR        SURVEY  OTHER STATES  ANIMALS & PRODUCTS
# 91          APR THRU JUN        SURVEY  OTHER STATES  ANIMALS & PRODUCTS
#
#     year_x  inventory_value  \
# 0     2020           8000.0
# 1     2020           8500.0
# 2     2020          32000.0
# 3     2020          26000.0
# 4     2020          17500.0
# ..     ...              ...
# 87    2020          53000.0
# 88    2020          17000.0
# 89    2020          24000.0
# 90    2020           8200.0
# 91    2020           7440.0
#
#                                          short_desc_x statisticcat_desc_x  \
# 0   HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...      INVENTORY, MAX
# 1   HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...      INVENTORY, MAX
# 2   HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...      INVENTORY, MAX
# 3   HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...      INVENTORY, MAX
# 4   HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...      INVENTORY, MAX
# ..                                                ...                 ...
# 87  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...      INVENTORY, MAX
# 88  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...      INVENTORY, MAX
# 89  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...      INVENTORY, MAX
# 90  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...      INVENTORY, MAX
# 91  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...      INVENTORY, MAX
#
#    source_desc_y       sector_desc_y  year_y  Value  \
# 0         SURVEY  ANIMALS & PRODUCTS    2020    0.1
# 1         SURVEY  ANIMALS & PRODUCTS    2020    7.7
# 2         SURVEY  ANIMALS & PRODUCTS    2020    0.0
# 3         SURVEY  ANIMALS & PRODUCTS    2020    4.2
# 4         SURVEY  ANIMALS & PRODUCTS    2020    2.6
# ..           ...                 ...     ...    ...
# 87        SURVEY  ANIMALS & PRODUCTS    2020   25.1
# 88        SURVEY  ANIMALS & PRODUCTS    2020    0.0
# 89        SURVEY  ANIMALS & PRODUCTS    2020    1.1
# 90        SURVEY  ANIMALS & PRODUCTS    2020    0.0
# 91        SURVEY  ANIMALS & PRODUCTS    2020    0.0
#
#                                          short_desc_y statisticcat_desc_y  \
# 0   HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...           INVENTORY
# 1   HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...           INVENTORY
# 2   HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...           INVENTORY
# 3   HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...           INVENTORY
# 4   HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...           INVENTORY
# ..                                                ...                 ...
# 87  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...           INVENTORY
# 88  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...           INVENTORY
# 89  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...           INVENTORY
# 90  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...           INVENTORY
# 91  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...           INVENTORY
#
#     pest_value
# 0          8.0
# 1        654.5
# 2          0.0
# 3       1092.0
# 4        455.0
# ..         ...
# 87     13303.0
# 88         0.0
# 89       264.0
# 90         0.0
# 91         0.0
#
# [92 rows x 15 columns]

# %%
(0.1*8000)/100
# Out:
# 8.0

# %%
inv_pest.head(1)
# Out:
#   reference_period_desc source_desc_x location_desc       sector_desc_x  \
# 0          JAN THRU MAR        SURVEY       ALABAMA  ANIMALS & PRODUCTS
#
#    year_x  inventory_value                                       short_desc_x  \
# 0    2020           8000.0  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...
#
#   statisticcat_desc_x source_desc_y       sector_desc_y  year_y  Value  \
# 0      INVENTORY, MAX        SURVEY  ANIMALS & PRODUCTS    2020    0.1
#
#                                         short_desc_y statisticcat_desc_y  \
# 0  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...           INVENTORY
#
#    pest_value
# 0         8.0

# %%
# need to compare pest_value in inv_pest dataframe with value column in usda_collapse_2020 dataframe.
#Grouped inventory_pesticide merged dataframe by location_desc and short_des column. Aggregated pest_value column. 
grouped_inv_pest=inv_pest.groupby(["location_desc", 'short_desc_x'])
grp_inv_pest_df=grouped_inv_pest.aggregate({'pest_value': 'sum'})
grp_inv_pest_df
# Out:
#                                                                    pest_value
# location_desc  short_desc_x
# ALABAMA        HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...       662.5
# ARIZONA        HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...      1092.0
# ARKANSAS       HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...      4637.0
# CALIFORNIA     HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...    155430.0
# COLORADO       HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...        64.0
# CONNECTICUT    HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...         0.0
# FLORIDA        HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...     34305.0
# GEORGIA        HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...      4653.0
# HAWAII         HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...         0.0
# IDAHO          HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...     11670.0
# ILLINOIS       HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...       996.0
# INDIANA        HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...      2757.5
# IOWA           HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...       274.0
# KANSAS         HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...      3170.0
# KENTUCKY       HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...       163.5
# LOUISIANA      HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...       629.0
# MAINE          HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...         0.0
# MARYLAND       HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...        88.0
# MASSACHUSETTS  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...        66.0
# MICHIGAN       HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...      4870.0
# MINNESOTA      HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...     11202.0
# MISSISSIPPI    HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...       837.0
# MISSOURI       HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...       337.5
# MONTANA        HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...         0.0
# NEBRASKA       HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...      4251.0
# NEW JERSEY     HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...        27.0
# NEW MEXICO     HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...        24.0
# NEW YORK       HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...       112.0
# NORTH CAROLINA HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...       138.0
# NORTH DAKOTA   HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...     11850.0
# OHIO           HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...       977.0
# OKLAHOMA       HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...       241.5
# OREGON         HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...     17750.0
# OTHER STATES   HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...         0.0
# PENNSYLVANIA   HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...       513.0
# SOUTH CAROLINA HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...        49.5
# SOUTH DAKOTA   HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...      1240.0
# TENNESSEE      HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...       918.0
# TEXAS          HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...     29270.0
# UTAH           HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...      4452.0
# VERMONT        HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...        67.5
# VIRGINIA       HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...        53.0
# WASHINGTON     HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...      1510.0
# WEST VIRGINIA  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...        85.5
# WISCONSIN      HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...     13303.0
# WYOMING        HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED ...       264.0

# %%
#Grouped CCD dataframe with location_desc and short_desc columns and aggregated the value for each state. 
grouped_usda_collapse_df=usda_collapse_2020.groupby(["location_desc", 'short_desc'])
grp_CCD_df=grouped_usda_collapse_df.aggregate({'Value': 'sum'})
grp_CCD_df
# Out:
#                                                                      Value
# location_desc  short_desc
# ALABAMA        HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...    480.0
# ARIZONA        HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...   4470.0
# ARKANSAS       HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...   1290.0
# CALIFORNIA     HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...  22200.0
# COLORADO       HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...    930.0
# CONNECTICUT    HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...     10.0
# FLORIDA        HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...  31000.0
# GEORGIA        HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...  11800.0
# HAWAII         HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...    260.0
# IDAHO          HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...   7900.0
# ILLINOIS       HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...    710.0
# INDIANA        HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...    240.0
# IOWA           HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...   1060.0
# KANSAS         HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...    970.0
# KENTUCKY       HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...    260.0
# LOUISIANA      HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...   1290.0
# MAINE          HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...     60.0
# MARYLAND       HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...    380.0
# MASSACHUSETTS  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...    200.0
# MICHIGAN       HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...   1820.0
# MINNESOTA      HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...   7370.0
# MISSISSIPPI    HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...   1060.0
# MISSOURI       HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...    360.0
# MONTANA        HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...   6000.0
# NEBRASKA       HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...   2200.0
# NEW JERSEY     HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...     70.0
# NEW MEXICO     HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...      0.0
# NEW YORK       HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...    960.0
# NORTH CAROLINA HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...   2190.0
# NORTH DAKOTA   HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...  20500.0
# OHIO           HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...   4030.0
# OKLAHOMA       HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...    100.0
# OREGON         HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...   2450.0
# PENNSYLVANIA   HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...    570.0
# SOUTH CAROLINA HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...    470.0
# SOUTH DAKOTA   HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...   3900.0
# TENNESSEE      HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...    620.0
# TEXAS          HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...   8300.0
# UTAH           HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...   1090.0
# VERMONT        HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...     60.0
# VIRGINIA       HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...    540.0
# WASHINGTON     HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...   6870.0
# WEST VIRGINIA  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...    330.0
# WISCONSIN      HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...   1690.0
# WYOMING        HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...   2000.0

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
from scipy import stats

from matplotlib import pyplot as plt

# %%
#grp_inv_pest_df["pest_value"]
#grp_inv_pest_df["location_desc"]

# %%
#Histogram of lost colonies to colony collapse disorder
plt.hist(grp_CCD_df["Value"], bins=20)
plt.show()

# %%
grp_CCD_df["Value"].min() #0.0
grp_CCD_df["Value"].max() # 31000

grp_inv_pest_df["pest_value"].min() #0.0
grp_inv_pest_df["pest_value"].max() #155430.0
len(grp_inv_pest_df) #46
len(grp_CCD_df) #45
# Out:
# 45

# %%
#Histogram of colonies affected by pesticides
plt.hist(grp_inv_pest_df["pest_value"], bins=20, color='red')
plt.show()

# %%
#Step histogram of both colony collapse disorder and pesticides
fig, ax = plt.subplots()
ax.hist(grp_CCD_df["Value"], label="Colony Collapse Disorder", histtype="step")
ax.hist(grp_inv_pest_df["pest_value"], label="Affected By Pesticides", histtype="step")
ax.set_xlabel("Number of Colonies Affected")
ax.set_ylabel("Number of States")
ax.legend()
plt.show()

# %%
#Box plot of both colony collapse disorder and colonies affected by pesticides
fig, ax = plt.subplots()
ax.boxplot([grp_CCD_df["Value"], grp_inv_pest_df["pest_value"]])
ax.set_xticklabels(["Colony Collapse Disorder", "Affected by Pesticides"])
ax.set_ylabel("Number of Colonies Affected")
plt.show()

# %%
#Scatter plot of both colonies affected by pesticides and colony collapse disorder
fig, ax = plt.subplots()
ax.scatter(usda_collapse_2020["location_desc"], usda_collapse_2020["Value"], color="red", label="Colony Collapse Disorder")
ax.scatter(inv_pest["location_desc"], inv_pest["pest_value"], color="blue", label="Affected by Pesticides")
ax.legend()
ax.set_xticklabels(usda_collapse_2020["location_desc"], rotation=90)
ax.set_xlabel("State")
ax.set_ylabel("Number of Colonies Affected")
plt.show()
# Out:
# <ipython-input-52-ca06adee99ff>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(usda_collapse_2020["location_desc"], rotation=90)

# %%
#Renamed the column 'Value' to 'value_ccd' in order to be able to merge this df into the one with the inventory and pesticide numbers
usda_collapse_2020_new=usda_collapse_2020.rename(columns={'Value': 'value_ccd' })

# %%
#Merge to get all value data in one place and grouped by state and time period
usda_total=pd.merge(inv_pest,usda_collapse_2020_new,how='outer',on=['reference_period_desc','location_desc'])
usda_total
# Out:
#    reference_period_desc source_desc_x location_desc       sector_desc_x  \
# 0           JAN THRU MAR        SURVEY       ALABAMA  ANIMALS & PRODUCTS
# 1           APR THRU JUN        SURVEY       ALABAMA  ANIMALS & PRODUCTS
# 2           JAN THRU MAR        SURVEY       ARIZONA  ANIMALS & PRODUCTS
# 3           APR THRU JUN        SURVEY       ARIZONA  ANIMALS & PRODUCTS
# 4           JAN THRU MAR        SURVEY      ARKANSAS  ANIMALS & PRODUCTS
# ..                   ...           ...           ...                 ...
# 87          APR THRU JUN        SURVEY     WISCONSIN  ANIMALS & PRODUCTS
# 88          JAN THRU MAR        SURVEY       WYOMING  ANIMALS & PRODUCTS
# 89          APR THRU JUN        SURVEY       WYOMING  ANIMALS & PRODUCTS
# 90          JAN THRU MAR        SURVEY  OTHER STATES  ANIMALS & PRODUCTS
# 91          APR THRU JUN        SURVEY  OTHER STATES  ANIMALS & PRODUCTS
#
#     year_x  inventory_value  \
# 0     2020           8000.0
# 1     2020           8500.0
# 2     2020          32000.0
# 3     2020          26000.0
# 4     2020          17500.0
# ..     ...              ...
# 87    2020          53000.0
# 88    2020          17000.0
# 89    2020          24000.0
# 90    2020           8200.0
# 91    2020           7440.0
#
#                                          short_desc_x statisticcat_desc_x  \
# 0   HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...      INVENTORY, MAX
# 1   HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...      INVENTORY, MAX
# 2   HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...      INVENTORY, MAX
# 3   HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...      INVENTORY, MAX
# 4   HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...      INVENTORY, MAX
# ..                                                ...                 ...
# 87  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...      INVENTORY, MAX
# 88  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...      INVENTORY, MAX
# 89  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...      INVENTORY, MAX
# 90  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...      INVENTORY, MAX
# 91  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...      INVENTORY, MAX
#
#    source_desc_y       sector_desc_y  ...  Value  \
# 0         SURVEY  ANIMALS & PRODUCTS  ...    0.1
# 1         SURVEY  ANIMALS & PRODUCTS  ...    7.7
# 2         SURVEY  ANIMALS & PRODUCTS  ...    0.0
# 3         SURVEY  ANIMALS & PRODUCTS  ...    4.2
# 4         SURVEY  ANIMALS & PRODUCTS  ...    2.6
# ..           ...                 ...  ...    ...
# 87        SURVEY  ANIMALS & PRODUCTS  ...   25.1
# 88        SURVEY  ANIMALS & PRODUCTS  ...    0.0
# 89        SURVEY  ANIMALS & PRODUCTS  ...    1.1
# 90        SURVEY  ANIMALS & PRODUCTS  ...    0.0
# 91        SURVEY  ANIMALS & PRODUCTS  ...    0.0
#
#                                          short_desc_y statisticcat_desc_y  \
# 0   HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...           INVENTORY
# 1   HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...           INVENTORY
# 2   HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...           INVENTORY
# 3   HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...           INVENTORY
# 4   HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...           INVENTORY
# ..                                                ...                 ...
# 87  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...           INVENTORY
# 88  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...           INVENTORY
# 89  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...           INVENTORY
# 90  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...           INVENTORY
# 91  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...           INVENTORY
#
#    pest_value  source_desc         sector_desc    year  value_ccd  \
# 0         8.0       SURVEY  ANIMALS & PRODUCTS  2020.0       70.0
# 1       654.5       SURVEY  ANIMALS & PRODUCTS  2020.0      410.0
# 2         0.0       SURVEY  ANIMALS & PRODUCTS  2020.0     4300.0
# 3      1092.0       SURVEY  ANIMALS & PRODUCTS  2020.0      170.0
# 4       455.0       SURVEY  ANIMALS & PRODUCTS  2020.0      390.0
# ..        ...          ...                 ...     ...        ...
# 87    13303.0       SURVEY  ANIMALS & PRODUCTS  2020.0       90.0
# 88        0.0       SURVEY  ANIMALS & PRODUCTS  2020.0     1500.0
# 89      264.0       SURVEY  ANIMALS & PRODUCTS  2020.0      500.0
# 90        0.0          NaN                 NaN     NaN        NaN
# 91        0.0          NaN                 NaN     NaN        NaN
#
#                                            short_desc  \
# 0   HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 1   HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 2   HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 3   HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 4   HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# ..                                                ...
# 87  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 88  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 89  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 90                                                NaN
# 91                                                NaN
#
#                  statisticcat_desc
# 0   LOSS, COLONY COLLAPSE DISORDER
# 1   LOSS, COLONY COLLAPSE DISORDER
# 2   LOSS, COLONY COLLAPSE DISORDER
# 3   LOSS, COLONY COLLAPSE DISORDER
# 4   LOSS, COLONY COLLAPSE DISORDER
# ..                             ...
# 87  LOSS, COLONY COLLAPSE DISORDER
# 88  LOSS, COLONY COLLAPSE DISORDER
# 89  LOSS, COLONY COLLAPSE DISORDER
# 90                             NaN
# 91                             NaN
#
# [92 rows x 21 columns]

# %%
#Calculated the percentage of colonies lost to CCD
ccd_perc=round((usda_total['value_ccd']/usda_total['inventory_value'])*100, 2)
ccd_perc
# Out:
# 0      0.88
# 1      4.82
# 2     13.44
# 3      0.65
# 4      2.23
#       ...
# 87     0.17
# 88     8.82
# 89     2.08
# 90      NaN
# 91      NaN
# Length: 92, dtype: float64

# %%
#Created a copy of df containing only percent of colonies affected by pesticides
usda_total_comp=usda_total[['location_desc', 'reference_period_desc', 'Value']]
usda_total_compare=usda_total_comp.copy()
#added the percentage lost to colony collapse
usda_total_compare['ccd_perc']=ccd_perc
#Changed column names to appropriately reflect the values
usda_total_compare.rename(columns={'Value': '%_Colonies_Affected_by_Pesticides', 'ccd_perc': "%_Colonies_Lost_to_Colony_Collapse_Disorder"}, inplace=True)
#Replace NaN values in "OTHER STATES" with 0
usda_total_compare["%_Colonies_Lost_to_Colony_Collapse_Disorder"] = usda_total_compare["%_Colonies_Lost_to_Colony_Collapse_Disorder"].fillna(0)
usda_total_compare['%_Colonies_Affected_by_Pesticides'] = usda_total_compare["%_Colonies_Affected_by_Pesticides"].fillna(0)
usda_total_compare
# Out:
#    location_desc reference_period_desc  %_Colonies_Affected_by_Pesticides  \
# 0        ALABAMA          JAN THRU MAR                                0.1
# 1        ALABAMA          APR THRU JUN                                7.7
# 2        ARIZONA          JAN THRU MAR                                0.0
# 3        ARIZONA          APR THRU JUN                                4.2
# 4       ARKANSAS          JAN THRU MAR                                2.6
# ..           ...                   ...                                ...
# 87     WISCONSIN          APR THRU JUN                               25.1
# 88       WYOMING          JAN THRU MAR                                0.0
# 89       WYOMING          APR THRU JUN                                1.1
# 90  OTHER STATES          JAN THRU MAR                                0.0
# 91  OTHER STATES          APR THRU JUN                                0.0
#
#     %_Colonies_Lost_to_Colony_Collapse_Disorder
# 0                                          0.88
# 1                                          4.82
# 2                                         13.44
# 3                                          0.65
# 4                                          2.23
# ..                                          ...
# 87                                         0.17
# 88                                         8.82
# 89                                         2.08
# 90                                         0.00
# 91                                         0.00
#
# [92 rows x 4 columns]

# %%
grp_usda_total_compare=usda_total_compare.groupby(usda_total_compare['location_desc']).sum()
#grp_usda_total_compare.aggregate({"%_Colonies_Affected_by_Pesticides": "sum",'%_Colonies_Lost_to_Colony_Collapse_Disorder':"sum"})
grp_usda_total_compare
# Out:
#                 %_Colonies_Affected_by_Pesticides  \
# location_desc
# ALABAMA                                       7.8
# ARIZONA                                       4.2
# ARKANSAS                                     27.2
# CALIFORNIA                                   10.7
# COLORADO                                      0.4
# CONNECTICUT                                   0.0
# FLORIDA                                      10.8
# GEORGIA                                       3.3
# HAWAII                                        0.0
# IDAHO                                        11.4
# ILLINOIS                                      8.3
# INDIANA                                      23.1
# IOWA                                          1.0
# KANSAS                                       40.6
# KENTUCKY                                      1.5
# LOUISIANA                                     1.3
# MAINE                                         0.0
# MARYLAND                                      1.1
# MASSACHUSETTS                                 0.7
# MICHIGAN                                      6.2
# MINNESOTA                                     9.0
# MISSISSIPPI                                   2.7
# MISSOURI                                      4.7
# MONTANA                                       0.0
# NEBRASKA                                     10.9
# NEW JERSEY                                    0.2
# NEW MEXICO                                    0.4
# NEW YORK                                      0.2
# NORTH CAROLINA                                0.6
# NORTH DAKOTA                                  3.0
# OHIO                                          5.9
# OKLAHOMA                                      1.4
# OREGON                                       16.7
# OTHER STATES                                  0.0
# PENNSYLVANIA                                  2.1
# SOUTH CAROLINA                                0.3
# SOUTH DAKOTA                                  2.5
# TENNESSEE                                     6.8
# TEXAS                                         8.0
# UTAH                                         15.4
# VERMONT                                       0.9
# VIRGINIA                                      0.7
# WASHINGTON                                    1.5
# WEST VIRGINIA                                 1.1
# WISCONSIN                                    25.1
# WYOMING                                       1.1
#
#                 %_Colonies_Lost_to_Colony_Collapse_Disorder
# location_desc
# ALABAMA                                                5.70
# ARIZONA                                               14.09
# ARKANSAS                                               7.52
# CALIFORNIA                                             1.38
# COLORADO                                               5.03
# CONNECTICUT                                            0.24
# FLORIDA                                                9.71
# GEORGIA                                                9.33
# HAWAII                                                 1.62
# IDAHO                                                  6.23
# ILLINOIS                                               5.58
# INDIANA                                                2.08
# IOWA                                                   4.47
# KANSAS                                                13.38
# KENTUCKY                                               2.42
# LOUISIANA                                              2.56
# MAINE                                                  3.53
# MARYLAND                                               5.07
# MASSACHUSETTS                                          4.12
# MICHIGAN                                               2.68
# MINNESOTA                                             12.09
# MISSISSIPPI                                            3.56
# MISSOURI                                               4.96
# MONTANA                                               10.63
# NEBRASKA                                              10.61
# NEW JERSEY                                             0.91
# NEW MEXICO                                             0.00
# NEW YORK                                               2.65
# NORTH CAROLINA                                         9.42
# NORTH DAKOTA                                          16.30
# OHIO                                                  20.29
# OKLAHOMA                                               0.56
# OREGON                                                 2.46
# OTHER STATES                                           0.00
# PENNSYLVANIA                                           2.31
# SOUTH CAROLINA                                         2.52
# SOUTH DAKOTA                                           6.87
# TENNESSEE                                              4.49
# TEXAS                                                  2.30
# UTAH                                                   6.07
# VERMONT                                                0.80
# VIRGINIA                                               7.41
# WASHINGTON                                             9.10
# WEST VIRGINIA                                          4.23
# WISCONSIN                                              6.32
# WYOMING                                               10.90

# %%
grp1_usda_total_compare=grp_usda_total_compare.head(23)
grp1_usda_total_compare
grp2_usda_total_compare=grp_usda_total_compare.tail(23)
grp2_usda_total_compare
# Out:
#                 %_Colonies_Affected_by_Pesticides  \
# location_desc
# MONTANA                                       0.0
# NEBRASKA                                     10.9
# NEW JERSEY                                    0.2
# NEW MEXICO                                    0.4
# NEW YORK                                      0.2
# NORTH CAROLINA                                0.6
# NORTH DAKOTA                                  3.0
# OHIO                                          5.9
# OKLAHOMA                                      1.4
# OREGON                                       16.7
# OTHER STATES                                  0.0
# PENNSYLVANIA                                  2.1
# SOUTH CAROLINA                                0.3
# SOUTH DAKOTA                                  2.5
# TENNESSEE                                     6.8
# TEXAS                                         8.0
# UTAH                                         15.4
# VERMONT                                       0.9
# VIRGINIA                                      0.7
# WASHINGTON                                    1.5
# WEST VIRGINIA                                 1.1
# WISCONSIN                                    25.1
# WYOMING                                       1.1
#
#                 %_Colonies_Lost_to_Colony_Collapse_Disorder
# location_desc
# MONTANA                                               10.63
# NEBRASKA                                              10.61
# NEW JERSEY                                             0.91
# NEW MEXICO                                             0.00
# NEW YORK                                               2.65
# NORTH CAROLINA                                         9.42
# NORTH DAKOTA                                          16.30
# OHIO                                                  20.29
# OKLAHOMA                                               0.56
# OREGON                                                 2.46
# OTHER STATES                                           0.00
# PENNSYLVANIA                                           2.31
# SOUTH CAROLINA                                         2.52
# SOUTH DAKOTA                                           6.87
# TENNESSEE                                              4.49
# TEXAS                                                  2.30
# UTAH                                                   6.07
# VERMONT                                                0.80
# VIRGINIA                                               7.41
# WASHINGTON                                             9.10
# WEST VIRGINIA                                          4.23
# WISCONSIN                                              6.32
# WYOMING                                               10.90

# %%
#Step histogram of both colony collapse disorder and pesticides percentages
fig, ax = plt.subplots()
ax.hist(usda_total_compare['%_Colonies_Lost_to_Colony_Collapse_Disorder'], label="Colony Collapse Disorder", histtype="step")
ax.hist(usda_total_compare['%_Colonies_Affected_by_Pesticides'], label="Affected By Pesticides", histtype="step")
ax.set_xlabel("Number of Colonies Affected")
ax.set_ylabel("Number of States")
ax.legend()
plt.show()

# %%
#Step histogram of both colony collapse disorder and pesticides percentages
fig, ax = plt.subplots()
ax.hist(grp_usda_total_compare['%_Colonies_Lost_to_Colony_Collapse_Disorder'], label="Colony Collapse Disorder", histtype="step")
ax.hist(grp_usda_total_compare['%_Colonies_Affected_by_Pesticides'], label="Affected By Pesticides", histtype="step")
ax.set_title("Loss of Bee Colonies with Colony Collapse Disorder and Pesticides", pad=20)
ax.set_xlabel("Number of Colonies Affected")
ax.set_ylabel("Number of States")
ax.legend()
plt.show()

# %%
#Box plot of both colony collapse disorder and colonies affected by pesticides percentages
fig, ax = plt.subplots()
ax.boxplot([usda_total_compare['%_Colonies_Affected_by_Pesticides'], usda_total_compare['%_Colonies_Lost_to_Colony_Collapse_Disorder']])
ax.set_xticklabels(["Colony Collapse Disorder", "Affected by Pesticides"])
ax.set_ylabel("Percent of Colonies Affected")
plt.show()

# %%
#Box plot of both colony collapse disorder and colonies affected by pesticides percentages
fig, ax = plt.subplots()
ax.boxplot([grp_usda_total_compare['%_Colonies_Affected_by_Pesticides'], grp_usda_total_compare['%_Colonies_Lost_to_Colony_Collapse_Disorder']])
ax.set_xticklabels(["Colony Collapse Disorder", "Affected by Pesticides"])
ax.set_ylabel("Percent of Colonies Affected")
plt.show()

# %%
#Created a scatterplot to reflect percentages of colony collapse disorder and colonies affected by pesticides
fig, ax = plt.subplots()
ax.scatter(usda_total_compare["location_desc"], usda_total_compare['%_Colonies_Lost_to_Colony_Collapse_Disorder'], color="red", label="Colony Collapse Disorder")
ax.scatter(usda_total_compare["location_desc"], usda_total_compare['%_Colonies_Affected_by_Pesticides'], color="blue", label="Affected by Pesticides")
ax.legend()
ax.set_xticklabels(usda_total_compare["location_desc"], rotation=90)
ax.set_xlabel("State")
ax.set_ylabel("Percent of Colonies Affected")
plt.show()
# Out:
# <ipython-input-131-d4a45b01b684>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(usda_total_compare["location_desc"], rotation=90)

# %%
#Created a scatterplot to reflect percentages of colony collapse disorder and colonies affected by pesticides
fig, ax = plt.subplots()
ax.scatter(grp1_usda_total_compare.index, grp1_usda_total_compare['%_Colonies_Lost_to_Colony_Collapse_Disorder'], color="red", label="Colony Collapse Disorder")
ax.scatter(grp1_usda_total_compare.index, grp1_usda_total_compare['%_Colonies_Affected_by_Pesticides'], color="blue", label="Affected by Pesticides")
ax.legend()
ax.set_title("Loss of Bee Colonies with Colony Collapse Disorder and Pesticides by State", pad=20)
ax.set_xticklabels(grp1_usda_total_compare.index, rotation=90)
ax.set_xlabel("State")
ax.set_ylabel("Percent of Colonies Affected")
plt.show()
# Out:
# <ipython-input-158-8f58e1575a87>:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(grp1_usda_total_compare.index, rotation=90)

# %%
#Created a scatterplot to reflect percentages of colony collapse disorder and colonies affected by pesticides
fig, ax = plt.subplots()
ax.scatter(grp2_usda_total_compare.index, grp2_usda_total_compare['%_Colonies_Lost_to_Colony_Collapse_Disorder'], color="red", label="Colony Collapse Disorder")
ax.scatter(grp2_usda_total_compare.index, grp2_usda_total_compare['%_Colonies_Affected_by_Pesticides'], color="blue", label="Affected by Pesticides")
ax.legend()
#Pad is spacing between title and plot
ax.set_title("Loss of Bee Colonies with Colony Collapse Disorder and Pesticides by State", pad=20)
ax.set_xticklabels(grp2_usda_total_compare.index, rotation=90)
ax.set_xlabel("State")
ax.set_ylabel("Percent of Colonies Affected")
plt.show()
# Out:
# <ipython-input-157-33cab636368a>:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(grp2_usda_total_compare.index, rotation=90)

# %%
usda_total_compare.describe()
# Out:
#        %_Colonies_Affected_by_Pesticides  \
# count                          92.000000
# mean                            3.052174
# std                             5.809721
# min                             0.000000
# 25%                             0.000000
# 50%                             0.500000
# 75%                             3.025000
# max                            32.800000
#
#        %_Colonies_Lost_to_Colony_Collapse_Disorder
# count                                    92.000000
# mean                                      2.875000
# std                                       3.539015
# min                                       0.000000
# 25%                                       0.680000
# 50%                                       1.580000
# 75%                                       3.575000
# max                                      19.500000

# %%
np.corrcoef(usda_total_compare['%_Colonies_Affected_by_Pesticides'], usda_total_compare['%_Colonies_Lost_to_Colony_Collapse_Disorder'] )
# Out:
# array([[ 1.        , -0.08112837],
#        [-0.08112837,  1.        ]])
