# %%
#### bee hives
import requests
import numpy as np
import pandas as pd
from pprint import pprint
apikey = "15B191E7-B8C5-3AF1-9E28-97FD910F9119"
usda_url ="http://quickstats.nass.usda.gov/api/api_GET/?key=15B191E7-B8C5-3AF1-9E28-97FD910F9119&source_desc=SURVEY&commodity_desc=HONEY&agg_level_desc=STATE&param=short_desc"
usda_data= requests.get(usda_url).json()
usda_data
#extracted data using API key and converted into JSON
# Out:
# {'data': [{'state_ansi': '01',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'end_code': '00',
#    'domain_desc': 'TOTAL',
#    'county_name': '',
#    'state_alpha': 'AL',
#    'country_name': 'UNITED STATES',
#    'source_desc': 'SURVEY',
#    'Value': '5.43',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'watershed_code': '00000000',
#    'state_name': 'ALABAMA',
#    'class_desc': 'ALL CLASSES',
#    'county_ansi': '',
#    'group_desc': 'SPECIALTY',
#    'week_ending': '',
#    'asd_desc': '',
#    'region_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'load_time': '2021-03-18 15:00:29',
#    'commodity_desc': 'HONEY',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'CV (%)': '',
#    'year': 2020,
#    'county_code': '',
#    'congr_district_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_code': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'domaincat_desc': 'NOT SPECIFIED',
# ...

# %%
usda_list = list(map(list, (usda_data.values())))
[usda_list1] = usda_list
new_usda_list = usda_list1
new_usda_list
# the output we have is a dictionary with two lists and a dictionary inside.
#removed outer 'data' dictionary here
# removed outer list with a new usda list
# Out:
# [{'state_ansi': '01',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'end_code': '00',
#   'domain_desc': 'TOTAL',
#   'county_name': '',
#   'state_alpha': 'AL',
#   'country_name': 'UNITED STATES',
#   'source_desc': 'SURVEY',
#   'Value': '5.43',
#   'statisticcat_desc': 'PRICE RECEIVED',
#   'watershed_code': '00000000',
#   'state_name': 'ALABAMA',
#   'class_desc': 'ALL CLASSES',
#   'county_ansi': '',
#   'group_desc': 'SPECIALTY',
#   'week_ending': '',
#   'asd_desc': '',
#   'region_desc': '',
#   'reference_period_desc': 'MARKETING YEAR',
#   'load_time': '2021-03-18 15:00:29',
#   'commodity_desc': 'HONEY',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'CV (%)': '',
#   'year': 2020,
#   'county_code': '',
#   'congr_district_code': '',
#   'sector_desc': 'ANIMALS & PRODUCTS',
#   'asd_code': '',
#   'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#   'domaincat_desc': 'NOT SPECIFIED',
#   'begin_code': '00',
# ...

# %%
usda_df=pd.DataFrame(new_usda_list)
usda_df
# Out:
#       state_ansi         util_practice_desc end_code domain_desc county_name  \
# 0             01  ALL UTILIZATION PRACTICES       00       TOTAL
# 1             01  ALL UTILIZATION PRACTICES       00       TOTAL
# 2             01  ALL UTILIZATION PRACTICES       00       TOTAL
# 3             04  ALL UTILIZATION PRACTICES       00       TOTAL
# 4             04  ALL UTILIZATION PRACTICES       00       TOTAL
# ...          ...                        ...      ...         ...         ...
# 21637             ALL UTILIZATION PRACTICES       12       TOTAL
# 21638             ALL UTILIZATION PRACTICES       03       TOTAL
# 21639             ALL UTILIZATION PRACTICES       06       TOTAL
# 21640             ALL UTILIZATION PRACTICES       09       TOTAL
# 21641             ALL UTILIZATION PRACTICES       12       TOTAL
#
#       state_alpha   country_name source_desc Value statisticcat_desc  ...  \
# 0              AL  UNITED STATES      SURVEY  5.43    PRICE RECEIVED  ...
# ...

# %%
usda_df.to_csv(r'C:\Users\watso\Documents\Data_Science_Bootcamp\exploratory_data_analysis_project\usda_df_to_clean.csv')

# %%
usda_clean_df=pd.read_excel(r'C:\Users\watso\Documents\Data_Science_Bootcamp\exploratory_data_analysis_project\usda_df_clean.xlsx')

# %%
usda_mod_df=usda_df[['group_desc','reference_period_desc', 'load_time', 'country_name', 'source_desc', 'country_code', 'location_desc', 'state_alpha', 'prodn_practice_desc', 'commodity_desc', 'sector_desc', 'agg_level_desc', 'class_desc', 'year',  'state_name', 'Value', 'short_desc', 'domaincat_desc', 'state_ansi', 'domain_desc', 'statisticcat_desc', 'util_practice_desc', 'freq_desc']]
usda_mod_df
# Out:
#       group_desc reference_period_desc            load_time   country_name  \
# 0      SPECIALTY        MARKETING YEAR  2021-03-18 15:00:29  UNITED STATES
# 1      SPECIALTY        MARKETING YEAR  2021-03-18 15:00:29  UNITED STATES
# 2      SPECIALTY        MARKETING YEAR  2020-03-19 15:06:59  UNITED STATES
# 3      SPECIALTY        MARKETING YEAR  2021-03-18 15:00:29  UNITED STATES
# 4      SPECIALTY        MARKETING YEAR  2021-03-18 15:00:29  UNITED STATES
# ...          ...                   ...                  ...            ...
# 21637  SPECIALTY          OCT THRU DEC  2017-08-01 15:00:29  UNITED STATES
# 21638  SPECIALTY          JAN THRU MAR  2016-05-12 15:09:03  UNITED STATES
# 21639  SPECIALTY          APR THRU JUN  2016-05-12 15:09:03  UNITED STATES
# 21640  SPECIALTY          JUL THRU SEP  2016-05-12 15:09:03  UNITED STATES
# 21641  SPECIALTY          OCT THRU DEC  2016-05-12 15:09:03  UNITED STATES
#
#       source_desc country_code location_desc state_alpha  \
# ...

# %%
usda_collapse_df = usda_mod_df[usda_mod_df['short_desc'].str.contains("COLONY COLLAPSE DISORDER")]
usda_collapse_df1 =usda_collapse_df[usda_collapse_df['year']==2020]
usda_collapse_df1
# Out:
#       group_desc reference_period_desc            load_time   country_name  \
# 17562  SPECIALTY          JAN THRU MAR  2020-08-03 15:00:16  UNITED STATES
# 17563  SPECIALTY          APR THRU JUN  2020-08-03 15:00:16  UNITED STATES
# 17567  SPECIALTY          JAN THRU MAR  2020-08-03 15:00:16  UNITED STATES
# 17568  SPECIALTY          APR THRU JUN  2020-08-03 15:00:16  UNITED STATES
# 17572  SPECIALTY          JAN THRU MAR  2020-08-03 15:00:16  UNITED STATES
# ...          ...                   ...                  ...            ...
# 17773  SPECIALTY          APR THRU JUN  2020-08-03 15:00:16  UNITED STATES
# 17777  SPECIALTY          JAN THRU MAR  2020-08-03 15:00:16  UNITED STATES
# 17778  SPECIALTY          APR THRU JUN  2020-08-03 15:00:16  UNITED STATES
# 17782  SPECIALTY          JAN THRU MAR  2020-08-03 15:00:16  UNITED STATES
# 17783  SPECIALTY          APR THRU JUN  2020-08-03 15:00:16  UNITED STATES
#
#       source_desc country_code  location_desc state_alpha  \
# ...

# %%
usda_mod_df=usda_df[['group_desc','reference_period_desc', 'load_time', 'country_name', 'source_desc', 'country_code', 'location_desc', 'state_alpha', 'prodn_practice_desc', 'commodity_desc', 'sector_desc', 'agg_level_desc', 'class_desc', 'year',  'state_name', 'Value', 'short_desc', 'domaincat_desc', 'state_ansi', 'domain_desc', 'statisticcat_desc', 'util_practice_desc', 'freq_desc']]
usda_mod_df
# Out:
#       group_desc reference_period_desc            load_time   country_name  \
# 0      SPECIALTY        MARKETING YEAR  2021-03-18 15:00:29  UNITED STATES
# 1      SPECIALTY        MARKETING YEAR  2021-03-18 15:00:29  UNITED STATES
# 2      SPECIALTY        MARKETING YEAR  2020-03-19 15:06:59  UNITED STATES
# 3      SPECIALTY        MARKETING YEAR  2021-03-18 15:00:29  UNITED STATES
# 4      SPECIALTY        MARKETING YEAR  2021-03-18 15:00:29  UNITED STATES
# ...          ...                   ...                  ...            ...
# 21637  SPECIALTY          OCT THRU DEC  2017-08-01 15:00:29  UNITED STATES
# 21638  SPECIALTY          JAN THRU MAR  2016-05-12 15:09:03  UNITED STATES
# 21639  SPECIALTY          APR THRU JUN  2016-05-12 15:09:03  UNITED STATES
# 21640  SPECIALTY          JUL THRU SEP  2016-05-12 15:09:03  UNITED STATES
# 21641  SPECIALTY          OCT THRU DEC  2016-05-12 15:09:03  UNITED STATES
#
#       source_desc country_code location_desc state_alpha  \
# ...

# %%
usda_collapse_df = usda_mod_df[usda_mod_df['short_desc'].str.contains("COLONY COLLAPSE DISORDER")]
usda_collapse_df1 = usda_collapse_df[usda_collapse_df['year']==2020]
usda_collapse_df1
# Out:
#       group_desc reference_period_desc            load_time   country_name  \
# 17562  SPECIALTY          JAN THRU MAR  2020-08-03 15:00:16  UNITED STATES
# 17563  SPECIALTY          APR THRU JUN  2020-08-03 15:00:16  UNITED STATES
# 17567  SPECIALTY          JAN THRU MAR  2020-08-03 15:00:16  UNITED STATES
# 17568  SPECIALTY          APR THRU JUN  2020-08-03 15:00:16  UNITED STATES
# 17572  SPECIALTY          JAN THRU MAR  2020-08-03 15:00:16  UNITED STATES
# ...          ...                   ...                  ...            ...
# 17773  SPECIALTY          APR THRU JUN  2020-08-03 15:00:16  UNITED STATES
# 17777  SPECIALTY          JAN THRU MAR  2020-08-03 15:00:16  UNITED STATES
# 17778  SPECIALTY          APR THRU JUN  2020-08-03 15:00:16  UNITED STATES
# 17782  SPECIALTY          JAN THRU MAR  2020-08-03 15:00:16  UNITED STATES
# 17783  SPECIALTY          APR THRU JUN  2020-08-03 15:00:16  UNITED STATES
#
#       source_desc country_code  location_desc state_alpha  \
# ...

# %%
usda_pesticide_df = usda_mod_df[usda_mod_df['short_desc'].str.contains("AFFECTED BY PESTICIDES")]
usda_pesticide_df1 = usda_pesticide_df[usda_pesticide_df['year']==2020]
usda_pesticide_df1
# Out:
#       group_desc reference_period_desc            load_time   country_name  \
# 9322   SPECIALTY          JAN THRU MAR  2020-08-03 15:00:16  UNITED STATES
# 9323   SPECIALTY          APR THRU JUN  2020-08-03 15:00:16  UNITED STATES
# 9343   SPECIALTY          JAN THRU MAR  2020-08-03 15:00:16  UNITED STATES
# 9344   SPECIALTY          APR THRU JUN  2020-08-03 15:00:16  UNITED STATES
# 9364   SPECIALTY          JAN THRU MAR  2020-08-03 15:00:16  UNITED STATES
# ...          ...                   ...                  ...            ...
# 10226  SPECIALTY          APR THRU JUN  2020-08-03 15:00:16  UNITED STATES
# 10246  SPECIALTY          JAN THRU MAR  2020-08-03 15:00:16  UNITED STATES
# 10247  SPECIALTY          APR THRU JUN  2020-08-03 15:00:16  UNITED STATES
# 10267  SPECIALTY          JAN THRU MAR  2020-08-03 15:00:16  UNITED STATES
# 10268  SPECIALTY          APR THRU JUN  2020-08-03 15:00:16  UNITED STATES
#
#       source_desc country_code location_desc state_alpha  \
# ...

# %%
usda_inventory_df = usda_mod_df[usda_mod_df['short_desc'].str.contains("INVENTORY, MAX,")]
usda_inventory_df1 = usda_inventory_df[usda_inventory_df['year']==2020]
usda_inventory_df1
# Out:
#       group_desc reference_period_desc            load_time   country_name  \
# 16596  SPECIALTY          JAN THRU MAR  2020-08-03 15:00:16  UNITED STATES
# 16597  SPECIALTY          APR THRU JUN  2020-08-03 15:00:16  UNITED STATES
# 16617  SPECIALTY          JAN THRU MAR  2020-08-03 15:00:16  UNITED STATES
# 16618  SPECIALTY          APR THRU JUN  2020-08-03 15:00:16  UNITED STATES
# 16638  SPECIALTY          JAN THRU MAR  2020-08-03 15:00:16  UNITED STATES
# ...          ...                   ...                  ...            ...
# 17500  SPECIALTY          APR THRU JUN  2020-08-03 15:00:16  UNITED STATES
# 17520  SPECIALTY          JAN THRU MAR  2020-08-03 15:00:16  UNITED STATES
# 17521  SPECIALTY          APR THRU JUN  2020-08-03 15:00:16  UNITED STATES
# 17541  SPECIALTY          JAN THRU MAR  2020-08-03 15:00:16  UNITED STATES
# 17542  SPECIALTY          APR THRU JUN  2020-08-03 15:00:16  UNITED STATES
#
#       source_desc country_code location_desc state_alpha  \
# ...

# %%
usda_mod_df2=usda_mod_df[['reference_period_desc', 'source_desc', 'location_desc', 'sector_desc', 'year', 'Value', 'short_desc', 'statisticcat_desc']]
usda_mod_df2
# Out:
#       reference_period_desc source_desc location_desc         sector_desc  \
# 0            MARKETING YEAR      SURVEY       ALABAMA  ANIMALS & PRODUCTS
# 1            MARKETING YEAR      SURVEY       ALABAMA  ANIMALS & PRODUCTS
# 2            MARKETING YEAR      SURVEY       ALABAMA  ANIMALS & PRODUCTS
# 3            MARKETING YEAR      SURVEY       ARIZONA  ANIMALS & PRODUCTS
# 4            MARKETING YEAR      SURVEY       ARIZONA  ANIMALS & PRODUCTS
# ...                     ...         ...           ...                 ...
# 21637          OCT THRU DEC      SURVEY  OTHER STATES  ANIMALS & PRODUCTS
# 21638          JAN THRU MAR      SURVEY  OTHER STATES  ANIMALS & PRODUCTS
# 21639          APR THRU JUN      SURVEY  OTHER STATES  ANIMALS & PRODUCTS
# 21640          JUL THRU SEP      SURVEY  OTHER STATES  ANIMALS & PRODUCTS
# 21641          OCT THRU DEC      SURVEY  OTHER STATES  ANIMALS & PRODUCTS
#
#        year Value                                         short_desc  \
# ...

# %%
usda_collapse_df2 = usda_mod_df2[usda_mod_df2['short_desc'].str.contains("COLONY COLLAPSE DISORDER")]
usda_collapse_df3 = usda_collapse_df2[usda_collapse_df2['year']==2020]
usda_collapse_df3
# Out:
#       reference_period_desc source_desc  location_desc         sector_desc  \
# 17562          JAN THRU MAR      SURVEY        ALABAMA  ANIMALS & PRODUCTS
# 17563          APR THRU JUN      SURVEY        ALABAMA  ANIMALS & PRODUCTS
# 17567          JAN THRU MAR      SURVEY        ARIZONA  ANIMALS & PRODUCTS
# 17568          APR THRU JUN      SURVEY        ARIZONA  ANIMALS & PRODUCTS
# 17572          JAN THRU MAR      SURVEY       ARKANSAS  ANIMALS & PRODUCTS
# ...                     ...         ...            ...                 ...
# 17773          APR THRU JUN      SURVEY  WEST VIRGINIA  ANIMALS & PRODUCTS
# 17777          JAN THRU MAR      SURVEY      WISCONSIN  ANIMALS & PRODUCTS
# 17778          APR THRU JUN      SURVEY      WISCONSIN  ANIMALS & PRODUCTS
# 17782          JAN THRU MAR      SURVEY        WYOMING  ANIMALS & PRODUCTS
# 17783          APR THRU JUN      SURVEY        WYOMING  ANIMALS & PRODUCTS
#
# ...

# %%
usda_pesticide_df2 = usda_mod_df2[usda_mod_df2['short_desc'].str.contains("AFFECTED BY PESTICIDES")]
usda_pesticide_df3 = usda_pesticide_df2[usda_pesticide_df2['year']==2020]
usda_pesticide_df3
# Out:
#       reference_period_desc source_desc location_desc         sector_desc  \
# 9322           JAN THRU MAR      SURVEY       ALABAMA  ANIMALS & PRODUCTS
# 9323           APR THRU JUN      SURVEY       ALABAMA  ANIMALS & PRODUCTS
# 9343           JAN THRU MAR      SURVEY       ARIZONA  ANIMALS & PRODUCTS
# 9344           APR THRU JUN      SURVEY       ARIZONA  ANIMALS & PRODUCTS
# 9364           JAN THRU MAR      SURVEY      ARKANSAS  ANIMALS & PRODUCTS
# ...                     ...         ...           ...                 ...
# 10226          APR THRU JUN      SURVEY     WISCONSIN  ANIMALS & PRODUCTS
# 10246          JAN THRU MAR      SURVEY       WYOMING  ANIMALS & PRODUCTS
# 10247          APR THRU JUN      SURVEY       WYOMING  ANIMALS & PRODUCTS
# 10267          JAN THRU MAR      SURVEY  OTHER STATES  ANIMALS & PRODUCTS
# 10268          APR THRU JUN      SURVEY  OTHER STATES  ANIMALS & PRODUCTS
#
#        year Value                                         short_desc  \
# ...

# %%
usda_pesticide_df3.to_csv(r'C:\Users\watso\Documents\Data_Science_Bootcamp\exploratory_data_analysis_project.csv')

# %%
usda_inventory_df2 = usda_mod_df2[usda_mod_df2['short_desc'].str.contains("INVENTORY, MAX,")]
usda_inventory_df3 = usda_inventory_df2[usda_inventory_df2['year']==2020]
usda_inventory_df3
# Out:
#       reference_period_desc source_desc location_desc         sector_desc  \
# 16596          JAN THRU MAR      SURVEY       ALABAMA  ANIMALS & PRODUCTS
# 16597          APR THRU JUN      SURVEY       ALABAMA  ANIMALS & PRODUCTS
# 16617          JAN THRU MAR      SURVEY       ARIZONA  ANIMALS & PRODUCTS
# 16618          APR THRU JUN      SURVEY       ARIZONA  ANIMALS & PRODUCTS
# 16638          JAN THRU MAR      SURVEY      ARKANSAS  ANIMALS & PRODUCTS
# ...                     ...         ...           ...                 ...
# 17500          APR THRU JUN      SURVEY     WISCONSIN  ANIMALS & PRODUCTS
# 17520          JAN THRU MAR      SURVEY       WYOMING  ANIMALS & PRODUCTS
# 17521          APR THRU JUN      SURVEY       WYOMING  ANIMALS & PRODUCTS
# 17541          JAN THRU MAR      SURVEY  OTHER STATES  ANIMALS & PRODUCTS
# 17542          APR THRU JUN      SURVEY  OTHER STATES  ANIMALS & PRODUCTS
#
#        year   Value                                         short_desc  \
# ...

# %%
usda_inventory_df3['Value']=usda_inventory_df3['Value'].str.replace(',','')
usda_inventory_df3
# Out:
# <ipython-input-73-29fd1bc283d7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_inventory_df3['Value']=usda_inventory_df3['Value'].str.replace(',','')
#       reference_period_desc source_desc location_desc         sector_desc  \
# 16596          JAN THRU MAR      SURVEY       ALABAMA  ANIMALS & PRODUCTS
# 16597          APR THRU JUN      SURVEY       ALABAMA  ANIMALS & PRODUCTS
# 16617          JAN THRU MAR      SURVEY       ARIZONA  ANIMALS & PRODUCTS
# 16618          APR THRU JUN      SURVEY       ARIZONA  ANIMALS & PRODUCTS
# 16638          JAN THRU MAR      SURVEY      ARKANSAS  ANIMALS & PRODUCTS
# ...                     ...         ...           ...                 ...
# ...

# %%
usda_inventory_df3['Value'].astype(float)
# Out:
# 16596     8000.0
# 16597     8500.0
# 16617    32000.0
# 16618    26000.0
# 16638    17500.0
#           ...
# 17500    53000.0
# 17520    17000.0
# 17521    24000.0
# 17541     8200.0
# 17542     7440.0
# Name: Value, Length: 92, dtype: float64

# %%
usda_pesticide_df3['Value']=usda_pesticide_df3['Value'].str.replace(' ','')
usda_pesticide_df3
# Out:
# <ipython-input-88-dcbe02f85e48>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_pesticide_df3['Value']=usda_pesticide_df3['Value'].str.replace(' ','')
#       reference_period_desc source_desc location_desc         sector_desc  \
# 9322           JAN THRU MAR      SURVEY       ALABAMA  ANIMALS & PRODUCTS
# 9323           APR THRU JUN      SURVEY       ALABAMA  ANIMALS & PRODUCTS
# 9343           JAN THRU MAR      SURVEY       ARIZONA  ANIMALS & PRODUCTS
# 9344           APR THRU JUN      SURVEY       ARIZONA  ANIMALS & PRODUCTS
# 9364           JAN THRU MAR      SURVEY      ARKANSAS  ANIMALS & PRODUCTS
# ...                     ...         ...           ...                 ...
# ...

# %%
usda_pesticide_df3['Value'].apply(lambda x: float(x))
usda_pesticide_df3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-df563a337964> in <module>
# ----> 1 usda_pesticide_df3['Value'].apply(lambda x: float(x))
#       2 usda_pesticide_df3
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-92-df563a337964> in <lambda>(x)
# ----> 1 usda_pesticide_df3['Value'].apply(lambda x: float(x))
#       2 usda_pesticide_df3
#
# ValueError: could not convert string to float: '(Z)'

# %%
grouped_usda_collapse_df=usda_collapse_df1.groupby(["location_desc", 'short_desc'])
grp_df1=grouped_usda_collapse_df.aggregate({'Value': 'sum'})
grp_df1
# Out:
#                                                                           Value
# location_desc  short_desc
# ALABAMA        HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...         70410
# ARIZONA        HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...      4,300170
# ARKANSAS       HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...        390900
# CALIFORNIA     HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...   19,0003,200
# COLORADO       HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...        620310
# CONNECTICUT    HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...           100
# FLORIDA        HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...  11,50019,500
# GEORGIA        HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...    8,5003,300
# HAWAII         HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...          2600
# IDAHO          HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DIS...    5,5002,400
# ...

# %%
grouped_usda_pesticide_df=usda_pesticide_df1.groupby(["location_desc", 'short_desc'])
grp_df2=grouped_usda_pesticide_df.aggregate({'Value':'sum'})
grp_df2
# Out:
#                                                                                       Value
# location_desc  short_desc
# ALABAMA        HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - I...                    0.17.7
# ARIZONA        HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - I...                      04.2
# ARKANSAS       HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - I...                   2.624.6
# CALIFORNIA     HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - I...                    5.35.4
# COLORADO       HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - I...                      0.40
# CONNECTICUT    HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - I...                        00
# FLORIDA        HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - I...                    5.35.5
# GEORGIA        HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - I...                      0.33
# HAWAII         HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - I...                        00
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# %%
fig, ax = plt.subplots()
ax.hist(grp_df1["Value"])
ax.set_xticklabels(grp_df1.index[], rotation=90)
ax.set_ylabel("Value")
plt.show()
# Out:
#   File "<ipython-input-63-4253d1c177f0>", line 3
#     ax.set_xticklabels(grp_df1.index[], rotation=90)
#                                      ^
# SyntaxError: invalid syntax
