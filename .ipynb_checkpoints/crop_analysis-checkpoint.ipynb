# %%
import requests
import pandas as pd
import numpy as np
import json
api_key ="34WxPcgCQYRxGz-bxxc_"
Wt_ind_url = "https://www.quandl.com/api/v3/datasets/UFAO/CR_WHET_IND?api_key=" +api_key
## wheat data from india
req_wt_ind = requests.get(Wt_ind_url).json()
req_wt_ind
# Out:
# {'dataset': {'id': 19754322,
#   'dataset_code': 'CR_WHET_IND',
#   'database_code': 'UFAO',
#   'name': 'Wheat Production in India',
#   'description': 'Wheat Production in India. The Food and Agriculture Organization generates wide-ranging data on many agricultural products from most countries and areas on a world-wide basis. For more info, please visit <a href=http://faostat.fao.org/>http://faostat.fao.org/</a>',
#   'refreshed_at': '2021-03-24T03:07:44.850Z',
#   'newest_available_date': '2018-12-31',
#   'oldest_available_date': '1961-12-31',
#   'column_names': ['Date',
#    'Area harvested - ha',
#    'Yield - hg/ha',
#    'Production - tonnes'],
#   'frequency': 'annual',
#   'type': 'Time Series',
#   'premium': False,
#   'limit': None,
#   'transform': None,
#   'column_index': None,
#   'start_date': '1961-12-31',
#   'end_date': '2018-12-31',
#   'data': [['2018-12-31', 29580000.0, 33705.0, 99700000.0],
#    ['2017-12-31', 30790000.0, 31994.0, 98510000.0],
# ...

# %%
wt_ind_df = pd.DataFrame(req_wt_ind)
wt_ind_df
# Out:
#                                                                  dataset
# collapse                                                            None
# column_index                                                        None
# column_names           [Date, Area harvested - ha, Yield - hg/ha, Pro...
# data                   [[2018-12-31, 29580000.0, 33705.0, 99700000.0]...
# database_code                                                       UFAO
# database_id                                                        13140
# dataset_code                                                 CR_WHET_IND
# description            Wheat Production in India. The Food and Agricu...
# end_date                                                      2018-12-31
# frequency                                                         annual
# id                                                              19754322
# limit                                                               None
# ...

# %%
Wt_usa_url = "https://www.quandl.com/api/v3/datasets/UFAO/CR_WHET_usa?api_key=" +api_key
req_wt_usa = requests.get(Wt_usa_url).json()
req_wt_usa
# Out:
# {'dataset': {'id': 19754391,
#   'dataset_code': 'CR_WHET_USA',
#   'database_code': 'UFAO',
#   'name': 'Wheat Production in United States of America',
#   'description': 'Wheat Production in United States of America. The Food and Agriculture Organization generates wide-ranging data on many agricultural products from most countries and areas on a world-wide basis. For more info, please visit <a href=http://faostat.fao.org/>http://faostat.fao.org/</a>',
#   'refreshed_at': '2021-03-24T03:07:47.846Z',
#   'newest_available_date': '2018-12-31',
#   'oldest_available_date': '1961-12-31',
#   'column_names': ['Date',
#    'Area harvested - ha',
#    'Yield - hg/ha',
#    'Production - tonnes'],
#   'frequency': 'annual',
#   'type': 'Time Series',
#   'premium': False,
#   'limit': None,
#   'transform': None,
#   'column_index': None,
#   'start_date': '1961-12-31',
#   'end_date': '2018-12-31',
#   'data': [['2018-12-31', 16027750.0, 31999.0, 51286540.0],
# ...
